# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np
import random
import timeit

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Use Citipy script to look up coordinates
from citipy import citipy 

# Import the API keys
from config import g_key

# Import the API key.
from config import weather_api_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID         City Country                 Date    Lat     Lng  Max Temp  \
# 0        0    Busselton      AU  2020-04-17 00:07:02 -33.65  115.33     55.99
# 1        1  Provideniya      RU  2020-04-17 00:06:31  64.38 -173.30     32.00
# 2        2       Hobart      AU  2020-04-17 00:06:02 -42.88  147.33     51.80
# 3        3         Lebu      CL  2020-04-17 00:07:03 -37.62  -73.65     56.30
# 4        4      Mataura      NZ  2020-04-17 00:07:03 -46.19  168.86     46.00
#
#    Humidity  Cloudiness  Wind Speed
# 0        61          13        8.05
# 1        97          90       13.42
# 2        53          75       21.92
# 3        87          10        8.70
# 4        94         100        8.01

# %%
# Create random integers
random.randint(-90,90)
# Out:
# 18

# %%
# Single floating-point decimal numbers
random.random()
# Out:
# 0.5303936787915232

# %%
# Generate a random latitude
random_number = random.randint(-90,90) + random.random()
random_number
# Out:
# -66.45100985041051

# %%
# Generate a group of floating latitudes
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 90) + random.random()
    latitudes.append(random_lat)
    x += 1
latitudes
# Out:
# [-38.66674323749856,
#  -45.40492860310584,
#  -85.65174190273603,
#  83.8296733031803,
#  15.617809164069811,
#  31.501630441777333,
#  -20.051083038005636,
#  -41.768386446732784,
#  35.7971597198882,
#  32.87185990461026]

# %%
# Create random numbers for longitude
random.randrange(-180,180, step=1)
# Out:
# -98

# %%
# Create random numbers for longitude 2
random.randrange(-180,180, step=3)
# Out:
# 90

# %%
# Generate a floating number
random.uniform(-180,180)
# Out:
# -27.576115061587387

# %%
# More floating numbers, now using NumPy
np.random.uniform(-90.000,90.000, size=50)
# Out:
# array([ 58.79129523,  84.8008088 ,  34.01249752,  34.04269041,
#        -88.35435395,  56.68462861,   3.66134531, -53.79057129,
#         69.979621  ,  84.164649  , -57.3657639 , -43.0252887 ,
#        -68.52378433, -64.42382298,  61.33513226, -36.51043231,
#         87.18926013,  55.8342032 , -34.14406044,   0.38449543,
#         79.40674156,  48.79883649, -61.73054263, -12.93699135,
#        -61.20738426,  42.36279305,   6.83482146, -84.73229737,
#        -31.4151132 , -57.0010161 ,  22.37309642,  72.0465727 ,
#        -78.58480615,  -9.63631758,   2.23304548, -59.56300773,
#         50.97470488, -23.35282844,  61.18037528,  -3.26405089,
#        -89.5830631 ,  16.24607407, -52.58158166, -37.75401513,
#        -88.90499693,  58.57750798,  28.20629045,  19.73022038,
#         83.67228575, -86.6421145 ])

# %%
# More floating numbers, now using NumPy, with increased parameter size
np.random.uniform(-90.000,90.000, size=1500)
# Out:
# array([-87.74337591, -85.37805206,  71.34234771, ..., -11.35335672,
#          1.63616198, -64.33643019])

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Practice a set of random lat/long combos
x = [25.12906645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x,y)

# %%
# Display lat/long combos
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12906645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add lat/long to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 607

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.status_code
# Out:
# 200

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"base":"stations","main":{"temp":43.83,"feels_like":34.86,"temp_min":42.01,"temp_max":45,"pressure":1016,"humidity":48},"visibility":16093,"wind":{"speed":8.05,"deg":200},"clouds":{"all":90},"dt":1587183980,"sys":{"type":1,"id":3486,"country":"US","sunrise":1587203852,"sunset":1587252538},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 43.83,
#   'feels_like': 34.86,
#   'temp_min': 42.01,
#   'temp_max': 45,
#   'pressure': 1016,
#   'humidity': 48},
#  'visibility': 16093,
#  'wind': {'speed': 8.05, 'deg': 200},
#  'clouds': {'all': 90},
#  'dt': 1587183980,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1587203852,
#   'sunset': 1587252538},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ilhabela
# City not found. Skipping...
# Processing Record 2 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 3 of Set 1 | jutai
# City not found. Skipping...
# Processing Record 4 of Set 1 | pevek
# City not found. Skipping...
# Processing Record 5 of Set 1 | port elizabeth
# City not found. Skipping...
# Processing Record 6 of Set 1 | camacha
# City not found. Skipping...
# Processing Record 7 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 8 of Set 1 | kavaratti
# City not found. Skipping...
# Processing Record 9 of Set 1 | shenjiamen
# City not found. Skipping...
# Processing Record 10 of Set 1 | cidreira
# City not found. Skipping...
# Processing Record 11 of Set 1 | qaanaaq
# City not found. Skipping...
# Processing Record 12 of Set 1 | honiara
# City not found. Skipping...
# Processing Record 13 of Set 1 | thompson
# City not found. Skipping...
# Processing Record 14 of Set 1 | taoudenni
# City not found. Skipping...
# Processing Record 15 of Set 1 | koson
# City not found. Skipping...
# Processing Record 16 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 17 of Set 1 | gat
# City not found. Skipping...
# Processing Record 18 of Set 1 | russell
# City not found. Skipping...
# Processing Record 19 of Set 1 | albany
# City not found. Skipping...
# Processing Record 20 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 21 of Set 1 | sulangan
# City not found. Skipping...
# Processing Record 22 of Set 1 | saint george
# City not found. Skipping...
# Processing Record 23 of Set 1 | georgetown
# City not found. Skipping...
# Processing Record 24 of Set 1 | berlevag
# City not found. Skipping...
# Processing Record 25 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 26 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 27 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 28 of Set 1 | ketchikan
# City not found. Skipping...
# Processing Record 29 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 30 of Set 1 | castro
# City not found. Skipping...
# Processing Record 31 of Set 1 | katsuura
# City not found. Skipping...
# Processing Record 32 of Set 1 | carnarvon
# City not found. Skipping...
# Processing Record 33 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 34 of Set 1 | provideniya
# City not found. Skipping...
# Processing Record 35 of Set 1 | broken hill
# City not found. Skipping...
# Processing Record 36 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 1 | xiongshi
# City not found. Skipping...
# Processing Record 38 of Set 1 | ouango
# City not found. Skipping...
# Processing Record 39 of Set 1 | avarua
# City not found. Skipping...
# Processing Record 40 of Set 1 | chuy
# City not found. Skipping...
# Processing Record 41 of Set 1 | vaini
# City not found. Skipping...
# Processing Record 42 of Set 1 | marabba
# City not found. Skipping...
# Processing Record 43 of Set 1 | faanui
# City not found. Skipping...
# Processing Record 44 of Set 1 | haines junction
# City not found. Skipping...
# Processing Record 45 of Set 1 | fort nelson
# City not found. Skipping...
# Processing Record 46 of Set 1 | ligayan
# City not found. Skipping...
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 1 | burley
# City not found. Skipping...
# Processing Record 50 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 1 of Set 2 | east london
# City not found. Skipping...
# Processing Record 2 of Set 2 | altamira
# City not found. Skipping...
# Processing Record 3 of Set 2 | iqaluit
# City not found. Skipping...
# Processing Record 4 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 2 | lebu
# City not found. Skipping...
# Processing Record 6 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 2 | grindavik
# City not found. Skipping...
# Processing Record 8 of Set 2 | salta
# City not found. Skipping...
# Processing Record 9 of Set 2 | awbari
# City not found. Skipping...
# Processing Record 10 of Set 2 | hofn
# City not found. Skipping...
# Processing Record 11 of Set 2 | arraial do cabo
# City not found. Skipping...
# Processing Record 12 of Set 2 | cortez
# City not found. Skipping...
# Processing Record 13 of Set 2 | victoria
# City not found. Skipping...
# Processing Record 14 of Set 2 | college
# City not found. Skipping...
# Processing Record 15 of Set 2 | kribi
# City not found. Skipping...
# Processing Record 16 of Set 2 | mount gambier
# City not found. Skipping...
# Processing Record 17 of Set 2 | port alfred
# City not found. Skipping...
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | souillac
# City not found. Skipping...
# Processing Record 20 of Set 2 | ixtapa
# City not found. Skipping...
# Processing Record 21 of Set 2 | bonthe
# City not found. Skipping...
# Processing Record 22 of Set 2 | ribeira grande
# City not found. Skipping...
# Processing Record 23 of Set 2 | adrar
# City not found. Skipping...
# Processing Record 24 of Set 2 | mahebourg
# City not found. Skipping...
# Processing Record 25 of Set 2 | erzin
# City not found. Skipping...
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | ushuaia
# City not found. Skipping...
# Processing Record 28 of Set 2 | klaksvik
# City not found. Skipping...
# Processing Record 29 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 2 | khatanga
# City not found. Skipping...
# Processing Record 31 of Set 2 | punta alta
# City not found. Skipping...
# Processing Record 32 of Set 2 | yokadouma
# City not found. Skipping...
# Processing Record 33 of Set 2 | north bend
# City not found. Skipping...
# Processing Record 34 of Set 2 | digby
# City not found. Skipping...
# Processing Record 35 of Set 2 | emirdag
# City not found. Skipping...
# Processing Record 36 of Set 2 | puerto escondido
# City not found. Skipping...
# Processing Record 37 of Set 2 | ponta do sol
# City not found. Skipping...
# Processing Record 38 of Set 2 | airai
# City not found. Skipping...
# Processing Record 39 of Set 2 | kruisfontein
# City not found. Skipping...
# Processing Record 40 of Set 2 | turukhansk
# City not found. Skipping...
# Processing Record 41 of Set 2 | micomeseng
# City not found. Skipping...
# Processing Record 42 of Set 2 | cherskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | coihaique
# City not found. Skipping...
# Processing Record 44 of Set 2 | saint anthony
# City not found. Skipping...
# Processing Record 45 of Set 2 | clyde river
# City not found. Skipping...
# Processing Record 46 of Set 2 | new norfolk
# City not found. Skipping...
# Processing Record 47 of Set 2 | bengkulu
# City not found. Skipping...
# Processing Record 48 of Set 2 | severo-kurilsk
# City not found. Skipping...
# Processing Record 49 of Set 2 | chitipa
# City not found. Skipping...
# Processing Record 50 of Set 2 | saskylakh
# City not found. Skipping...
# Processing Record 1 of Set 3 | portland
# City not found. Skipping...
# Processing Record 2 of Set 3 | margate
# City not found. Skipping...
# Processing Record 3 of Set 3 | yako
# City not found. Skipping...
# Processing Record 4 of Set 3 | hithadhoo
# City not found. Skipping...
# Processing Record 5 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 3 | ilulissat
# City not found. Skipping...
# Processing Record 8 of Set 3 | goya
# City not found. Skipping...
# Processing Record 9 of Set 3 | punta arenas
# City not found. Skipping...
# Processing Record 10 of Set 3 | bukan
# City not found. Skipping...
# Processing Record 11 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 12 of Set 3 | nikolskoye
# City not found. Skipping...
# Processing Record 13 of Set 3 | shizukuishi
# City not found. Skipping...
# Processing Record 14 of Set 3 | tongchuan
# City not found. Skipping...
# Processing Record 15 of Set 3 | puerto leguizamo
# City not found. Skipping...
# Processing Record 16 of Set 3 | pisco
# City not found. Skipping...
# Processing Record 17 of Set 3 | tysons corner
# City not found. Skipping...
# Processing Record 18 of Set 3 | hamilton
# City not found. Skipping...
# Processing Record 19 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 3 | coahuayana
# City not found. Skipping...
# Processing Record 21 of Set 3 | moissac
# City not found. Skipping...
# Processing Record 22 of Set 3 | dzerzhinskoye
# City not found. Skipping...
# Processing Record 23 of Set 3 | caravelas
# City not found. Skipping...
# Processing Record 24 of Set 3 | plyussa
# City not found. Skipping...
# Processing Record 25 of Set 3 | cabo san lucas
# City not found. Skipping...
# Processing Record 26 of Set 3 | araouane
# City not found. Skipping...
# Processing Record 27 of Set 3 | jieshi
# City not found. Skipping...
# Processing Record 28 of Set 3 | hilo
# City not found. Skipping...
# Processing Record 29 of Set 3 | marawi
# City not found. Skipping...
# Processing Record 30 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 3 | tucuru
# City not found. Skipping...
# Processing Record 32 of Set 3 | celestun
# City not found. Skipping...
# Processing Record 33 of Set 3 | sergio osmena sr
# City not found. Skipping...
# Processing Record 34 of Set 3 | sao francisco do sul
# City not found. Skipping...
# Processing Record 35 of Set 3 | antofagasta
# City not found. Skipping...
# Processing Record 36 of Set 3 | stettler
# City not found. Skipping...
# Processing Record 37 of Set 3 | san patricio
# City not found. Skipping...
# Processing Record 38 of Set 3 | dunedin
# City not found. Skipping...
# Processing Record 39 of Set 3 | hobart
# City not found. Skipping...
# Processing Record 40 of Set 3 | bethel
# City not found. Skipping...
# Processing Record 41 of Set 3 | mount isa
# City not found. Skipping...
# Processing Record 42 of Set 3 | kapaa
# City not found. Skipping...
# Processing Record 43 of Set 3 | namwala
# City not found. Skipping...
# Processing Record 44 of Set 3 | lahaina
# City not found. Skipping...
# Processing Record 45 of Set 3 | czersk
# City not found. Skipping...
# Processing Record 46 of Set 3 | ahipara
# City not found. Skipping...
# Processing Record 47 of Set 3 | fortuna
# City not found. Skipping...
# Processing Record 48 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 3 | mar del plata
# City not found. Skipping...
# Processing Record 50 of Set 3 | kavieng
# City not found. Skipping...
# Processing Record 1 of Set 4 | nemcice nad hanou
# City not found. Skipping...
# Processing Record 2 of Set 4 | grahamstown
# City not found. Skipping...
# Processing Record 3 of Set 4 | bathsheba
# City not found. Skipping...
# Processing Record 4 of Set 4 | cape town
# City not found. Skipping...
# Processing Record 5 of Set 4 | salalah
# City not found. Skipping...
# Processing Record 6 of Set 4 | henties bay
# City not found. Skipping...
# Processing Record 7 of Set 4 | bubaque
# City not found. Skipping...
# Processing Record 8 of Set 4 | poum
# City not found. Skipping...
# Processing Record 9 of Set 4 | necochea
# City not found. Skipping...
# Processing Record 10 of Set 4 | kaitangata
# City not found. Skipping...
# Processing Record 11 of Set 4 | hami
# City not found. Skipping...
# Processing Record 12 of Set 4 | mahibadhoo
# City not found. Skipping...
# Processing Record 13 of Set 4 | upernavik
# City not found. Skipping...
# Processing Record 14 of Set 4 | vardo
# City not found. Skipping...
# Processing Record 15 of Set 4 | makakilo city
# City not found. Skipping...
# Processing Record 16 of Set 4 | saint-philippe
# City not found. Skipping...
# Processing Record 17 of Set 4 | bayir
# City not found. Skipping...
# Processing Record 18 of Set 4 | birao
# City not found. Skipping...
# Processing Record 19 of Set 4 | sao joao da barra
# City not found. Skipping...
# Processing Record 20 of Set 4 | sorong
# City not found. Skipping...
# Processing Record 21 of Set 4 | korla
# City not found. Skipping...
# Processing Record 22 of Set 4 | igrim
# City not found. Skipping...
# Processing Record 23 of Set 4 | khani
# City not found. Skipping...
# Processing Record 24 of Set 4 | san policarpo
# City not found. Skipping...
# Processing Record 25 of Set 4 | meulaboh
# City not found. Skipping...
# Processing Record 26 of Set 4 | opuwo
# City not found. Skipping...
# Processing Record 27 of Set 4 | karpathos
# City not found. Skipping...
# Processing Record 28 of Set 4 | kirakira
# City not found. Skipping...
# Processing Record 29 of Set 4 | pittsburg
# City not found. Skipping...
# Processing Record 30 of Set 4 | selma
# City not found. Skipping...
# Processing Record 31 of Set 4 | kidal
# City not found. Skipping...
# Processing Record 32 of Set 4 | nouadhibou
# City not found. Skipping...
# Processing Record 33 of Set 4 | amapa
# City not found. Skipping...
# Processing Record 34 of Set 4 | kostyantynivka
# City not found. Skipping...
# Processing Record 35 of Set 4 | lompoc
# City not found. Skipping...
# Processing Record 36 of Set 4 | dipkarpaz
# City not found. Skipping...
# Processing Record 37 of Set 4 | te anau
# City not found. Skipping...
# Processing Record 38 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 4 | barrow
# City not found. Skipping...
# Processing Record 40 of Set 4 | casalmaggiore
# City not found. Skipping...
# Processing Record 41 of Set 4 | salinopolis
# City not found. Skipping...
# Processing Record 42 of Set 4 | lerwick
# City not found. Skipping...
# Processing Record 43 of Set 4 | ugoofaaru
# City not found. Skipping...
# Processing Record 44 of Set 4 | khuzdar
# City not found. Skipping...
# Processing Record 45 of Set 4 | santiago del estero
# City not found. Skipping...
# Processing Record 46 of Set 4 | dukat
# City not found. Skipping...
# Processing Record 47 of Set 4 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 48 of Set 4 | oranjemund
# City not found. Skipping...
# Processing Record 49 of Set 4 | olafsvik
# City not found. Skipping...
# Processing Record 50 of Set 4 | atambua
# City not found. Skipping...
# Processing Record 1 of Set 5 | zuwarah
# City not found. Skipping...
# Processing Record 2 of Set 5 | hermanus
# City not found. Skipping...
# Processing Record 3 of Set 5 | la joya
# City not found. Skipping...
# Processing Record 4 of Set 5 | yumen
# City not found. Skipping...
# Processing Record 5 of Set 5 | talnakh
# City not found. Skipping...
# Processing Record 6 of Set 5 | aitape
# City not found. Skipping...
# Processing Record 7 of Set 5 | bucerias
# City not found. Skipping...
# Processing Record 8 of Set 5 | alofi
# City not found. Skipping...
# Processing Record 9 of Set 5 | gizo
# City not found. Skipping...
# Processing Record 10 of Set 5 | sao sebastiao
# City not found. Skipping...
# Processing Record 11 of Set 5 | peachtree city
# City not found. Skipping...
# Processing Record 12 of Set 5 | norman wells
# City not found. Skipping...
# Processing Record 13 of Set 5 | lichuan
# City not found. Skipping...
# Processing Record 14 of Set 5 | basoko
# City not found. Skipping...
# Processing Record 15 of Set 5 | san rafael del sur
# City not found. Skipping...
# Processing Record 16 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 17 of Set 5 | aklavik
# City not found. Skipping...
# Processing Record 18 of Set 5 | tasiilaq
# City not found. Skipping...
# Processing Record 19 of Set 5 | terrace
# City not found. Skipping...
# Processing Record 20 of Set 5 | moindou
# City not found. Skipping...
# Processing Record 21 of Set 5 | alice springs
# City not found. Skipping...
# Processing Record 22 of Set 5 | simplicio mendes
# City not found. Skipping...
# Processing Record 23 of Set 5 | nishihara
# City not found. Skipping...
# Processing Record 24 of Set 5 | sao filipe
# City not found. Skipping...
# Processing Record 25 of Set 5 | kobojango
# City not found. Skipping...
# Processing Record 26 of Set 5 | kampot
# City not found. Skipping...
# Processing Record 27 of Set 5 | kangaba
# City not found. Skipping...
# Processing Record 28 of Set 5 | faya
# City not found. Skipping...
# Processing Record 29 of Set 5 | kodiak
# City not found. Skipping...
# Processing Record 30 of Set 5 | butaritari
# City not found. Skipping...
# Processing Record 31 of Set 5 | jamestown
# City not found. Skipping...
# Processing Record 32 of Set 5 | leningradskiy
# City not found. Skipping...
# Processing Record 33 of Set 5 | broome
# City not found. Skipping...
# Processing Record 34 of Set 5 | oshakati
# City not found. Skipping...
# Processing Record 35 of Set 5 | chokurdakh
# City not found. Skipping...
# Processing Record 36 of Set 5 | zelenogorskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | dubbo
# City not found. Skipping...
# Processing Record 38 of Set 5 | san nicolas
# City not found. Skipping...
# Processing Record 39 of Set 5 | zhuji
# City not found. Skipping...
# Processing Record 40 of Set 5 | prieska
# City not found. Skipping...
# Processing Record 41 of Set 5 | saint-augustin
# City not found. Skipping...
# Processing Record 42 of Set 5 | vieux-habitants
# City not found. Skipping...
# Processing Record 43 of Set 5 | rengo
# City not found. Skipping...
# Processing Record 44 of Set 5 | santa eulalia
# City not found. Skipping...
# Processing Record 45 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 46 of Set 5 | nizhniy tsasuchey
# City not found. Skipping...
# Processing Record 47 of Set 5 | kamaishi
# City not found. Skipping...
# Processing Record 48 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 5 | koumac
# City not found. Skipping...
# Processing Record 50 of Set 5 | poya
# City not found. Skipping...
# Processing Record 1 of Set 6 | jalu
# City not found. Skipping...
# Processing Record 2 of Set 6 | presidente epitacio
# City not found. Skipping...
# Processing Record 3 of Set 6 | omboue
# City not found. Skipping...
# Processing Record 4 of Set 6 | nantucket
# City not found. Skipping...
# Processing Record 5 of Set 6 | san juan
# City not found. Skipping...
# Processing Record 6 of Set 6 | krasnoye-na-volge
# City not found. Skipping...
# Processing Record 7 of Set 6 | tsurib
# City not found. Skipping...
# Processing Record 8 of Set 6 | tiksi
# City not found. Skipping...
# Processing Record 9 of Set 6 | waukesha
# City not found. Skipping...
# Processing Record 10 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 6 | stykkisholmur
# City not found. Skipping...
# Processing Record 12 of Set 6 | mudgee
# City not found. Skipping...
# Processing Record 13 of Set 6 | champerico
# City not found. Skipping...
# Processing Record 14 of Set 6 | bulgan
# City not found. Skipping...
# Processing Record 15 of Set 6 | najran
# City not found. Skipping...
# Processing Record 16 of Set 6 | salamiyah
# City not found. Skipping...
# Processing Record 17 of Set 6 | silifke
# City not found. Skipping...
# Processing Record 18 of Set 6 | bud
# City not found. Skipping...
# Processing Record 19 of Set 6 | vanersborg
# City not found. Skipping...
# Processing Record 20 of Set 6 | harper
# City not found. Skipping...
# Processing Record 21 of Set 6 | gawler
# City not found. Skipping...
# Processing Record 22 of Set 6 | cabra
# City not found. Skipping...
# Processing Record 23 of Set 6 | lavrentiya
# City not found. Skipping...
# Processing Record 24 of Set 6 | okhotsk
# City not found. Skipping...
# Processing Record 25 of Set 6 | torbay
# City not found. Skipping...
# Processing Record 26 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 27 of Set 6 | ostrovnoy
# City not found. Skipping...
# Processing Record 28 of Set 6 | cap malheureux
# City not found. Skipping...
# Processing Record 29 of Set 6 | tanda
# City not found. Skipping...
# Processing Record 30 of Set 6 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 31 of Set 6 | avera
# City not found. Skipping...
# Processing Record 32 of Set 6 | surt
# City not found. Skipping...
# Processing Record 33 of Set 6 | turan
# City not found. Skipping...
# Processing Record 34 of Set 6 | miri
# City not found. Skipping...
# Processing Record 35 of Set 6 | coquimbo
# City not found. Skipping...
# Processing Record 36 of Set 6 | kununurra
# City not found. Skipping...
# Processing Record 37 of Set 6 | mayo
# City not found. Skipping...
# Processing Record 38 of Set 6 | bay roberts
# City not found. Skipping...
# Processing Record 39 of Set 6 | moses lake
# City not found. Skipping...
# Processing Record 40 of Set 6 | lorengau
# City not found. Skipping...
# Processing Record 41 of Set 6 | manavgat
# City not found. Skipping...
# Processing Record 42 of Set 6 | san francisco
# City not found. Skipping...
# Processing Record 43 of Set 6 | paamiut
# City not found. Skipping...
# Processing Record 44 of Set 6 | crawfordsville
# City not found. Skipping...
# Processing Record 45 of Set 6 | vila franca do campo
# City not found. Skipping...
# Processing Record 46 of Set 6 | carauari
# City not found. Skipping...
# Processing Record 47 of Set 6 | balkanabat
# City not found. Skipping...
# Processing Record 48 of Set 6 | tres arroyos
# City not found. Skipping...
# Processing Record 49 of Set 6 | ozernovskiy
# City not found. Skipping...
# Processing Record 50 of Set 6 | evensk
# City not found. Skipping...
# Processing Record 1 of Set 7 | chabahar
# City not found. Skipping...
# Processing Record 2 of Set 7 | denpasar
# City not found. Skipping...
# Processing Record 3 of Set 7 | emerald
# City not found. Skipping...
# Processing Record 4 of Set 7 | concarneau
# City not found. Skipping...
# Processing Record 5 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 7 | ucluelet
# City not found. Skipping...
# Processing Record 7 of Set 7 | paengaroa
# City not found. Skipping...
# Processing Record 8 of Set 7 | tilichiki
# City not found. Skipping...
# Processing Record 9 of Set 7 | rathdrum
# City not found. Skipping...
# Processing Record 10 of Set 7 | mandera
# City not found. Skipping...
# Processing Record 11 of Set 7 | sitka
# City not found. Skipping...
# Processing Record 12 of Set 7 | bonga
# City not found. Skipping...
# Processing Record 13 of Set 7 | namibe
# City not found. Skipping...
# Processing Record 14 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 7 | pangnirtung
# City not found. Skipping...
# Processing Record 17 of Set 7 | hun
# City not found. Skipping...
# Processing Record 18 of Set 7 | biggar
# City not found. Skipping...
# Processing Record 19 of Set 7 | leshukonskoye
# City not found. Skipping...
# Processing Record 20 of Set 7 | kizukuri
# City not found. Skipping...
# Processing Record 21 of Set 7 | upata
# City not found. Skipping...
# Processing Record 22 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 23 of Set 7 | pampa
# City not found. Skipping...
# Processing Record 24 of Set 7 | gorele
# City not found. Skipping...
# Processing Record 25 of Set 7 | kupang
# City not found. Skipping...
# Processing Record 26 of Set 7 | juquia
# City not found. Skipping...
# Processing Record 27 of Set 7 | vuktyl
# City not found. Skipping...
# Processing Record 28 of Set 7 | manzil jamil
# City not found. Skipping...
# Processing Record 29 of Set 7 | duz
# City not found. Skipping...
# Processing Record 30 of Set 7 | kongolo
# City not found. Skipping...
# Processing Record 31 of Set 7 | tuatapere
# City not found. Skipping...
# Processing Record 32 of Set 7 | kochubey
# City not found. Skipping...
# Processing Record 33 of Set 7 | prince rupert
# City not found. Skipping...
# Processing Record 34 of Set 7 | inongo
# City not found. Skipping...
# Processing Record 35 of Set 7 | yar-sale
# City not found. Skipping...
# Processing Record 36 of Set 7 | dauriya
# City not found. Skipping...
# Processing Record 37 of Set 7 | sinnamary
# City not found. Skipping...
# Processing Record 38 of Set 7 | weyburn
# City not found. Skipping...
# Processing Record 39 of Set 7 | tautira
# City not found. Skipping...
# Processing Record 40 of Set 7 | codrington
# City not found. Skipping...
# Processing Record 41 of Set 7 | saldanha
# City not found. Skipping...
# Processing Record 42 of Set 7 | guerrero negro
# City not found. Skipping...
# Processing Record 43 of Set 7 | okha
# City not found. Skipping...
# Processing Record 44 of Set 7 | wajima
# City not found. Skipping...
# Processing Record 45 of Set 7 | matay
# City not found. Skipping...
# Processing Record 46 of Set 7 | mizdah
# City not found. Skipping...
# Processing Record 47 of Set 7 | oranjestad
# City not found. Skipping...
# Processing Record 48 of Set 7 | iwaki
# City not found. Skipping...
# Processing Record 49 of Set 7 | cache creek
# City not found. Skipping...
# Processing Record 50 of Set 7 | laguna
# City not found. Skipping...
# Processing Record 1 of Set 8 | cockburn town
# City not found. Skipping...
# Processing Record 2 of Set 8 | ambilobe
# City not found. Skipping...
# Processing Record 3 of Set 8 | qaqortoq
# City not found. Skipping...
# Processing Record 4 of Set 8 | longyearbyen
# City not found. Skipping...
# Processing Record 5 of Set 8 | chepareria
# City not found. Skipping...
# Processing Record 6 of Set 8 | nanortalik
# City not found. Skipping...
# Processing Record 7 of Set 8 | berdigestyakh
# City not found. Skipping...
# Processing Record 8 of Set 8 | husavik
# City not found. Skipping...
# Processing Record 9 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 10 of Set 8 | terenos
# City not found. Skipping...
# Processing Record 11 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 8 | lagoa
# City not found. Skipping...
# Processing Record 13 of Set 8 | petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 14 of Set 8 | praya
# City not found. Skipping...
# Processing Record 15 of Set 8 | muros
# City not found. Skipping...
# Processing Record 16 of Set 8 | wangqing
# City not found. Skipping...
# Processing Record 17 of Set 8 | kandrian
# City not found. Skipping...
# Processing Record 18 of Set 8 | villa bruzual
# City not found. Skipping...
# Processing Record 19 of Set 8 | santa maria
# City not found. Skipping...
# Processing Record 20 of Set 8 | jiaohe
# City not found. Skipping...
# Processing Record 21 of Set 8 | vaitape
# City not found. Skipping...
# Processing Record 22 of Set 8 | walvis bay
# City not found. Skipping...
# Processing Record 23 of Set 8 | port hardy
# City not found. Skipping...
# Processing Record 24 of Set 8 | juneau
# City not found. Skipping...
# Processing Record 25 of Set 8 | touros
# City not found. Skipping...
# Processing Record 26 of Set 8 | la tuque
# City not found. Skipping...
# Processing Record 27 of Set 8 | banda aceh
# City not found. Skipping...
# Processing Record 28 of Set 8 | kahului
# City not found. Skipping...
# Processing Record 29 of Set 8 | feldkirchen
# City not found. Skipping...
# Processing Record 30 of Set 8 | samarkand
# City not found. Skipping...
# Processing Record 31 of Set 8 | bambous virieux
# City not found. Skipping...
# Processing Record 32 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 33 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 8 | mizan teferi
# City not found. Skipping...
# Processing Record 35 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 8 | asfi
# City not found. Skipping...
# Processing Record 37 of Set 8 | veraval
# City not found. Skipping...
# Processing Record 38 of Set 8 | mogadishu
# City not found. Skipping...
# Processing Record 39 of Set 8 | grand bank
# City not found. Skipping...
# Processing Record 40 of Set 8 | udachnyy
# City not found. Skipping...
# Processing Record 41 of Set 8 | tabou
# City not found. Skipping...
# Processing Record 42 of Set 8 | narsaq
# City not found. Skipping...
# Processing Record 43 of Set 8 | lethem
# City not found. Skipping...
# Processing Record 44 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 45 of Set 8 | kosya
# City not found. Skipping...
# Processing Record 46 of Set 8 | abnub
# City not found. Skipping...
# Processing Record 47 of Set 8 | deer lake
# City not found. Skipping...
# Processing Record 48 of Set 8 | cayenne
# City not found. Skipping...
# Processing Record 49 of Set 8 | tura
# City not found. Skipping...
# Processing Record 50 of Set 8 | namatanai
# City not found. Skipping...
# Processing Record 1 of Set 9 | ancud
# City not found. Skipping...
# Processing Record 2 of Set 9 | qeshm
# City not found. Skipping...
# Processing Record 3 of Set 9 | ushtobe
# City not found. Skipping...
# Processing Record 4 of Set 9 | gimli
# City not found. Skipping...
# Processing Record 5 of Set 9 | maracaju
# City not found. Skipping...
# Processing Record 6 of Set 9 | rio grande
# City not found. Skipping...
# Processing Record 7 of Set 9 | sao jose da coroa grande
# City not found. Skipping...
# Processing Record 8 of Set 9 | binzhou
# City not found. Skipping...
# Processing Record 9 of Set 9 | hambantota
# City not found. Skipping...
# Processing Record 10 of Set 9 | vung tau
# City not found. Skipping...
# Processing Record 11 of Set 9 | kalanchak
# City not found. Skipping...
# Processing Record 12 of Set 9 | olinda
# City not found. Skipping...
# Processing Record 13 of Set 9 | mochicahui
# City not found. Skipping...
# Processing Record 14 of Set 9 | yining
# City not found. Skipping...
# Processing Record 15 of Set 9 | kutum
# City not found. Skipping...
# Processing Record 16 of Set 9 | isangel
# City not found. Skipping...
# Processing Record 17 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 9 | padang
# City not found. Skipping...
# Processing Record 19 of Set 9 | bozeman
# City not found. Skipping...
# Processing Record 20 of Set 9 | nakasongola
# City not found. Skipping...
# Processing Record 21 of Set 9 | tual
# City not found. Skipping...
# Processing Record 22 of Set 9 | zaqatala
# City not found. Skipping...
# Processing Record 23 of Set 9 | sattur
# City not found. Skipping...
# Processing Record 24 of Set 9 | masuguru
# City not found. Skipping...
# Processing Record 25 of Set 9 | nemuro
# City not found. Skipping...
# Processing Record 26 of Set 9 | ahuimanu
# City not found. Skipping...
# Processing Record 27 of Set 9 | palauig
# City not found. Skipping...
# Processing Record 28 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 29 of Set 9 | huarmey
# City not found. Skipping...
# Processing Record 30 of Set 9 | juazeiro
# City not found. Skipping...
# Processing Record 31 of Set 9 | les cayes
# City not found. Skipping...
# Processing Record 32 of Set 9 | iringa
# City not found. Skipping...
# Processing Record 33 of Set 9 | roebourne
# City not found. Skipping...
# Processing Record 34 of Set 9 | imeni poliny osipenko
# City not found. Skipping...
# Processing Record 35 of Set 9 | vastervik
# City not found. Skipping...
# Processing Record 36 of Set 9 | ha tinh
# City not found. Skipping...
# Processing Record 37 of Set 9 | goba
# City not found. Skipping...
# Processing Record 38 of Set 9 | port hedland
# City not found. Skipping...
# Processing Record 39 of Set 9 | tezu
# City not found. Skipping...
# Processing Record 40 of Set 9 | nadvoitsy
# City not found. Skipping...
# Processing Record 41 of Set 9 | oltu
# City not found. Skipping...
# Processing Record 42 of Set 9 | osmena
# City not found. Skipping...
# Processing Record 43 of Set 9 | tanabe
# City not found. Skipping...
# Processing Record 44 of Set 9 | borovoy
# City not found. Skipping...
# Processing Record 45 of Set 9 | semey
# City not found. Skipping...
# Processing Record 46 of Set 9 | roald
# City not found. Skipping...
# Processing Record 47 of Set 9 | lang son
# City not found. Skipping...
# Processing Record 48 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 9 | golden
# City not found. Skipping...
# Processing Record 50 of Set 9 | macae
# City not found. Skipping...
# Processing Record 1 of Set 10 | voznesenskoye
# City not found. Skipping...
# Processing Record 2 of Set 10 | dolgorukovo
# City not found. Skipping...
# Processing Record 3 of Set 10 | iquique
# City not found. Skipping...
# Processing Record 4 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 10 | villa sandino
# City not found. Skipping...
# Processing Record 6 of Set 10 | burewala
# City not found. Skipping...
# Processing Record 7 of Set 10 | santo tomas
# City not found. Skipping...
# Processing Record 8 of Set 10 | chipinge
# City not found. Skipping...
# Processing Record 9 of Set 10 | rampur hat
# City not found. Skipping...
# Processing Record 10 of Set 10 | hongjiang
# City not found. Skipping...
# Processing Record 11 of Set 10 | arklow
# City not found. Skipping...
# Processing Record 12 of Set 10 | luderitz
# City not found. Skipping...
# Processing Record 13 of Set 10 | dikson
# City not found. Skipping...
# Processing Record 14 of Set 10 | shadegan
# City not found. Skipping...
# Processing Record 15 of Set 10 | general roca
# City not found. Skipping...
# Processing Record 16 of Set 10 | deputatskiy
# City not found. Skipping...
# Processing Record 17 of Set 10 | rawson
# City not found. Skipping...
# Processing Record 18 of Set 10 | yulara
# City not found. Skipping...
# Processing Record 19 of Set 10 | betul
# City not found. Skipping...
# Processing Record 20 of Set 10 | farsund
# City not found. Skipping...
# Processing Record 21 of Set 10 | kanniyakumari
# City not found. Skipping...
# Processing Record 22 of Set 10 | gorontalo
# City not found. Skipping...
# Processing Record 23 of Set 10 | san jose
# City not found. Skipping...
# Processing Record 24 of Set 10 | hoi an
# City not found. Skipping...
# Processing Record 25 of Set 10 | along
# City not found. Skipping...
# Processing Record 26 of Set 10 | atar
# City not found. Skipping...
# Processing Record 27 of Set 10 | maba
# City not found. Skipping...
# Processing Record 28 of Set 10 | kapuskasing
# City not found. Skipping...
# Processing Record 29 of Set 10 | bilibino
# City not found. Skipping...
# Processing Record 30 of Set 10 | kasempa
# City not found. Skipping...
# Processing Record 31 of Set 10 | soyo
# City not found. Skipping...
# Processing Record 32 of Set 10 | springbok
# City not found. Skipping...
# Processing Record 33 of Set 10 | balma
# City not found. Skipping...
# Processing Record 34 of Set 10 | kabare
# City not found. Skipping...
# Processing Record 35 of Set 10 | la ronge
# City not found. Skipping...
# Processing Record 36 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 10 | paramonga
# City not found. Skipping...
# Processing Record 38 of Set 10 | nyrob
# City not found. Skipping...
# Processing Record 39 of Set 10 | marzuq
# City not found. Skipping...
# Processing Record 40 of Set 10 | kachiry
# City not found. Skipping...
# Processing Record 41 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 42 of Set 10 | tucurui
# City not found. Skipping...
# Processing Record 43 of Set 10 | bhadrachalam
# City not found. Skipping...
# Processing Record 44 of Set 10 | haicheng
# City not found. Skipping...
# Processing Record 45 of Set 10 | manokwari
# City not found. Skipping...
# Processing Record 46 of Set 10 | thyboron
# City not found. Skipping...
# Processing Record 47 of Set 10 | kalabo
# City not found. Skipping...
# Processing Record 48 of Set 10 | aktash
# City not found. Skipping...
# Processing Record 49 of Set 10 | sorland
# City not found. Skipping...
# Processing Record 50 of Set 10 | chongwe
# City not found. Skipping...
# Processing Record 1 of Set 11 | zhangye
# City not found. Skipping...
# Processing Record 2 of Set 11 | karratha
# City not found. Skipping...
# Processing Record 3 of Set 11 | belyy yar
# City not found. Skipping...
# Processing Record 4 of Set 11 | yuncheng
# City not found. Skipping...
# Processing Record 5 of Set 11 | escarcega
# City not found. Skipping...
# Processing Record 6 of Set 11 | kyren
# City not found. Skipping...
# Processing Record 7 of Set 11 | kungurtug
# City not found. Skipping...
# Processing Record 8 of Set 11 | cachoeira do sul
# City not found. Skipping...
# Processing Record 9 of Set 11 | nombre de dios
# City not found. Skipping...
# Processing Record 10 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 11 of Set 11 | beidao
# City not found. Skipping...
# Processing Record 12 of Set 11 | tiarei
# City not found. Skipping...
# Processing Record 13 of Set 11 | akdepe
# City not found. Skipping...
# Processing Record 14 of Set 11 | jalingo
# City not found. Skipping...
# Processing Record 15 of Set 11 | praxedis guerrero
# City not found. Skipping...
# Processing Record 16 of Set 11 | xaxim
# City not found. Skipping...
# Processing Record 17 of Set 11 | tateyama
# City not found. Skipping...
# Processing Record 18 of Set 11 | lanester
# City not found. Skipping...
# Processing Record 19 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 11 | bereda
# City not found. Skipping...
# Processing Record 21 of Set 11 | assiniboia
# City not found. Skipping...
# Processing Record 22 of Set 11 | tabuk
# City not found. Skipping...
# Processing Record 23 of Set 11 | viransehir
# City not found. Skipping...
# Processing Record 24 of Set 11 | bukoba
# City not found. Skipping...
# Processing Record 25 of Set 11 | anjiang
# City not found. Skipping...
# Processing Record 26 of Set 11 | pavlodar
# City not found. Skipping...
# Processing Record 27 of Set 11 | kalmunai
# City not found. Skipping...
# Processing Record 28 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 29 of Set 11 | changde
# City not found. Skipping...
# Processing Record 30 of Set 11 | naze
# City not found. Skipping...
# Processing Record 31 of Set 11 | dingle
# City not found. Skipping...
# Processing Record 32 of Set 11 | carpinteria
# City not found. Skipping...
# Processing Record 33 of Set 11 | labuhan
# City not found. Skipping...
# Processing Record 34 of Set 11 | madera
# City not found. Skipping...
# Processing Record 35 of Set 11 | vanavara
# City not found. Skipping...
# Processing Record 36 of Set 11 | pandak
# City not found. Skipping...
# Processing Record 37 of Set 11 | guarda
# City not found. Skipping...
# Processing Record 38 of Set 11 | shetpe
# City not found. Skipping...
# Processing Record 39 of Set 11 | yarim
# City not found. Skipping...
# Processing Record 40 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 11 | lander
# City not found. Skipping...
# Processing Record 42 of Set 11 | aksarka
# City not found. Skipping...
# Processing Record 43 of Set 11 | santa isabel do rio negro
# City not found. Skipping...
# Processing Record 44 of Set 11 | burica
# City not found. Skipping...
# Processing Record 45 of Set 11 | hay river
# City not found. Skipping...
# Processing Record 46 of Set 11 | lagunas
# City not found. Skipping...
# Processing Record 47 of Set 11 | sechura
# City not found. Skipping...
# Processing Record 48 of Set 11 | alangayam
# City not found. Skipping...
# Processing Record 49 of Set 11 | camocim
# City not found. Skipping...
# Processing Record 50 of Set 11 | taytay
# City not found. Skipping...
# Processing Record 1 of Set 12 | planovskoye
# City not found. Skipping...
# Processing Record 2 of Set 12 | nhamunda
# City not found. Skipping...
# Processing Record 3 of Set 12 | arona
# City not found. Skipping...
# Processing Record 4 of Set 12 | harqalah
# City not found. Skipping...
# Processing Record 5 of Set 12 | moree
# City not found. Skipping...
# Processing Record 6 of Set 12 | mindelo
# City not found. Skipping...
# Processing Record 7 of Set 12 | saint-pierre
# City not found. Skipping...
# Processing Record 8 of Set 12 | morros
# City not found. Skipping...
# Processing Record 9 of Set 12 | menongue
# City not found. Skipping...
# Processing Record 10 of Set 12 | shimoda
# City not found. Skipping...
# Processing Record 11 of Set 12 | sukabumi
# City not found. Skipping...
# Processing Record 12 of Set 12 | peniche
# City not found. Skipping...
# Processing Record 13 of Set 12 | shelburne
# City not found. Skipping...
# Processing Record 14 of Set 12 | tiznit
# City not found. Skipping...
# Processing Record 15 of Set 12 | sukumo
# City not found. Skipping...
# Processing Record 16 of Set 12 | grafton
# City not found. Skipping...
# Processing Record 17 of Set 12 | kharan
# City not found. Skipping...
# Processing Record 18 of Set 12 | moron
# City not found. Skipping...
# Processing Record 19 of Set 12 | cabedelo
# City not found. Skipping...
# Processing Record 20 of Set 12 | fairbanks
# City not found. Skipping...
# Processing Record 21 of Set 12 | tooele
# City not found. Skipping...
# Processing Record 22 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 23 of Set 12 | terra rica
# City not found. Skipping...
# Processing Record 24 of Set 12 | iwanai
# City not found. Skipping...
# Processing Record 25 of Set 12 | marsabit
# City not found. Skipping...
# Processing Record 26 of Set 12 | ambositra
# City not found. Skipping...
# Processing Record 27 of Set 12 | nenjiang
# City not found. Skipping...
# Processing Record 28 of Set 12 | cartagena
# City not found. Skipping...
# Processing Record 29 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 12 | puerto el triunfo
# City not found. Skipping...
# Processing Record 31 of Set 12 | vila velha
# City not found. Skipping...
# Processing Record 32 of Set 12 | havre-saint-pierre
# City not found. Skipping...
# Processing Record 33 of Set 12 | shahrud
# City not found. Skipping...
# Processing Record 34 of Set 12 | makungu
# City not found. Skipping...
# Processing Record 35 of Set 12 | domvraina
# City not found. Skipping...
# Processing Record 36 of Set 12 | pangkalanbuun
# City not found. Skipping...
# Processing Record 37 of Set 12 | eravur
# City not found. Skipping...
# Processing Record 38 of Set 12 | nelidovo
# City not found. Skipping...
# Processing Record 39 of Set 12 | pedro juan caballero
# City not found. Skipping...
# Processing Record 40 of Set 12 | nicoya
# City not found. Skipping...
# Processing Record 41 of Set 12 | bonfim
# City not found. Skipping...
# Processing Record 42 of Set 12 | beaverlodge
# City not found. Skipping...
# Processing Record 43 of Set 12 | bassano
# City not found. Skipping...
# Processing Record 44 of Set 12 | esmeraldas
# City not found. Skipping...
# Processing Record 45 of Set 12 | mpigi
# City not found. Skipping...
# Processing Record 46 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 12 | svetlyy
# City not found. Skipping...
# Processing Record 48 of Set 12 | leghorn
# City not found. Skipping...
# Processing Record 49 of Set 12 | ceuta
# City not found. Skipping...
# Processing Record 50 of Set 12 | porbandar
# City not found. Skipping...
# Processing Record 1 of Set 13 | teya
# City not found. Skipping...
# Processing Record 2 of Set 13 | fujin
# City not found. Skipping...
# Processing Record 3 of Set 13 | flagstaff
# City not found. Skipping...
# Processing Record 4 of Set 13 | businga
# City not found. Skipping...
# Processing Record 5 of Set 13 | general pico
# City not found. Skipping...
# Processing Record 6 of Set 13 | leh
# City not found. Skipping...
# Processing Record 7 of Set 13 | rabo de peixe
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
                    #######       Part 1 Instructions       #######
#Get the Weather Description and Amount of Precipitation for Each City

#To complete this task, follow these steps:
    #1. Create a new Jupyter Notebook file and name it Weather_Database.ipynb.
   
    #2. Generate a new set of 1,500 random latitudes and longitudes.
   
    #3. Get the nearest city using the citipy module.
    
    #4. Perform an API call with the OpenWeatherMap.
    
    #5. Retrieve the following information from the API call:
            #Latitude and longitude
            #Maximum temperature
            #Percent humidity
            #Percent cloudiness
            #Wind speed
            #Weather description (e.g., clouds, fog, light rain, clear sky)
            #Using a try-except block, in the try block if it is raining, get the amount of rainfall in inches for the last three hours. In the except block handle the KeyError if there is no rainfall and add 0 inches for the rainfall amount.
            #Using a try-except block, in the try block if it is snowing, get the amount of snowfall in inches for the last three hours. In the except block handle the KeyError if there is no snowfall and add 0 inches for the snowfall amount.
    
    #6. Add the data to a new DataFrame.
    
    #7. Save the new DataFrame as a CSV file to be used for Part 2.
    
    #8. Upload the CSV file as part of your submission as WeatherPy_challenge.csv.
    
    #9. Answer this question using Pandas methods: How many cities have recorded rainfall or snow?

# %% [markdown]
# ## This is a test
#
# ### This is only a test

# %%
                            #######        Part 2 Instructions       #######
#Have Customers Narrow Their Travel Searches Based on Temperature and Precipitation

#To complete this task, follow these steps:

    #1. Create a new Jupyter Notebook file and name it Vacation_Search.ipynb.
    
    #2. Import the WeatherPy_vacation.csv file from Part 1 as a new DataFrame.
    
    #3. Filter the DataFrame for minimum and maximum temperature preferences, and if the rain or snow accumulation is 0 inches or not using conditional statements. Do the following:
            #Prompt the customer for the minimum temperature preference.
            #Prompt the customer for the maximum temperature preference.
            #Prompt the customer to answer if he or she would like it to be raining or not, using input("Do you want it to be raining? (yes/no) ").
            #Prompt the customer to answer if he or she would like it to be snowing or not, using input("Do you want it to be snowing? (yes/no) ").
    
    #4. Add the cities to a marker layer map with a pop-up marker for each city that includes:
            #Hotel name
            #City
            #Country
            #Current weather description with the maximum temperature
    
    #5. Save and upload the new DataFrame as WeatherPy_vacation.csv.
    
    #6. Save and upload the new marker layer map as WeatherPy_vacation_map.png.

# %%
                                #######       Part 3 Instructions       #######
#Create a Travel Itinerary with a Corresponding Map

#Finally, you will create a map (travel itinerary) that shows the route between four cities from the customer’s possible travel destinations, and then create a map with pop-up markers for the four cities. To complete these tasks, follow these steps:
    #1. Enable the “Directions API” in your Google account for your API key.
            #On the Google Cloud Platform, select APIs from the left-hand side.
            #Viewing the options on the Google Cloud Platform
            #Then, select "Directions API."
            #Viewing the APIs on your Google Account
            #Click “Enable” on the Directions API. 
             #Viewing the APIs on your Google Account. 

    #2. Create a new Jupyter Notebook file and label it Vacation_Itinerary.ipynb.
    
    #3. Import the WeatherPy_vacation.csv file as a new DataFrame.
    
    #4. From the vacation search map, choose at least four cities in close proximity on your map that are on the same continent that a customer might travel to, and then create a directions layer map.
        #Hints:
            #Filter the DataFrame for each city you want to go to and create separate DataFrames for each city.
            #Use the directions Layer instructions from the gmaps documentation (Links to an external site.).
            #Use the list indexing and Pandas methods to get the latitude-longitude pairs for each city DataFrame as tuples.
    
    #5. For the travel_mode, use either DRIVING, BICYCLING, or WALKING.
        #Hint: If the cities are too far apart, some travel modes will not be available.
    
    #6. Take a screenshot of the route and save it as WeatherPy_travel_map.png.
    
    #7. Create a marker layer map for the four cities.
        #Hint: Create a new DataFrame that has all the individual city DataFrames you created.

    #8. On the marker layer map, make sure each city has a pop-up marker that contains the following:
            #Hotel name
            #City
            #Country
            #Current weather description with the maximum temperature

    #9. Take a screenshot of the marker layer map for the route and save it as WeatherPy_travel_map_markers.png.

#The directions layer map should look similar to the following image:

#The directions layer for the vacation itinerary.

#The pop-up marker for each city in the vacation itinerary look similar to the following image:
