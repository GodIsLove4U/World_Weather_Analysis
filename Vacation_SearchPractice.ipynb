# %% [markdown]
# ## Module 6 Challenge
# ### Doris B. Cohen, April 2020 -------> Part 2
#
# Part 2 Instructions
# Have Customers Narrow Their Travel Searches Based on Temperature and Precipitation
# To complete this task, follow these steps:
#
# 1. Create a new Jupyter Notebook file and name it Vacation_Search.ipynb.
# 2. Import the WeatherPy_vacation.csv file from Part 1 as a new DataFrame.
# 3. Filter the DataFrame for minimum and maximum temperature preferences, and if the rain or snow accumulation is 0 inches or not using conditional statements. Do the following:
#     Prompt the customer for the minimum temperature preference.
#     Prompt the customer for the maximum temperature preference.
#     Prompt the customer to answer if he or she would like it to be raining or not, using input("Do you want it to be raining? (yes/no) ").
#     Prompt the customer to answer if he or she would like it to be snowing or not, using input("Do you want it to be snowing? (yes/no) ").
# 4. Add the cities to a marker layer map with a pop-up marker for each city that includes:
#     Hotel name
#     City
#     Country
#     Current weather description with the maximum temperature
# 5. Save and upload the new DataFrame as WeatherPy_vacation.csv.
# 6. Save and upload the new marker layer map as WeatherPy_vacation_map.png.

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests

# Import the API key.
from config import g_key

# %%
# Read file from Part 1
city_vacay_df = pd.read_csv("weather_data/WeatherPy.csv")
city_vacay_df.head()
# Out:
#    City_ID        City Country                 Date    Lat     Lng  Max Temp  \
# 0        0  Rio Grande      BR  2020-04-19 01:14:32 -32.03  -52.10     64.99
# 1        1   Jamestown      US  2020-04-19 01:17:49  42.10  -79.24     43.00
# 2        2    Tolyatti      RU  2020-04-19 01:18:30  53.53   49.35     32.00
# 3        3     Rikitea      PF  2020-04-19 01:18:30 -23.12 -134.97     77.49
# 4        4      Avarua      CK  2020-04-19 01:18:31 -21.21 -159.78     82.40
#
#    Humidity  Cloudiness  Wind Speed   Weather Desc Rain/Inches Snow
# 0        91           0        1.01      clear sky           0    0
# 1        55           1        3.36      clear sky           0    0
# 2        79           0        6.71      clear sky           0    0
# 3        69          21        6.42     few clouds           0    0
# 4        69          70        6.93  broken clouds           0    0

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 110

# %%
# Find out if the vacationer is okay with rain
rain = input("Do you want it to be raining? (yes/no) ")
# Out:
# Do you want it to be raining? (yes/no) yes

# %%
# Find out if the vacationer is okay with snow
snow = input("Do you want it to be snowing? (yes/no) ")
# Out:
# Do you want it to be snowing? (yes/no) no

# %%
# Match criteria to answers
if rain == "no" and snow == "no":
    answer_filter_df = city_vacay_df.loc[(city_vacay_df["Max Temp"]<= max_temp) &
                                    (city_vacay_df["Max Temp"] >= min_temp) &
                                    (city_vacay_df["Rain/Inches"] == 0) &
                                    (city_vacay_df["Snow"] == 0)]

else:
    answer_filter_df = city_vacay_df.loc[(city_vacay_df["Max Temp"]<= max_temp) &
                                    (city_vacay_df["Max Temp"] >= min_temp) &
                                    (city_vacay_df["Rain/Inches"] == 0) &
                                    (city_vacay_df["Snow"] == 0)]

# %%
# Match criteria to answers
if rain == "no" and snow == "no":
    answer_filter_df = city_vacay_df.loc[(city_vacay_df["Max Temp"]<= max_temp) &
                                    (city_vacay_df["Max Temp"] >= min_temp) &
                                    (city_vacay_df["Rain/Inches"] == 0) &
                                    (city_vacay_df["Snow"] == 0)]

elif rain == "no" and snow == "yes":
    answer_filter_df = city_vacay_df.loc[(city_vacay_df["Max Temp"]<= max_temp) &
                                    (city_vacay_df["Max Temp"] >= min_temp) &
                                    (city_vacay_df["Rain/Inches"] == 0) &
                                    (city_vacay_df["Snow"] == 0)]

elif rain == "yes" and snow == "no":
    answer_filter_df = city_vacay_df.loc[(city_vacay_df["Max Temp"]<= max_temp) &
                                    (city_vacay_df["Max Temp"] >= min_temp) &
                                    (city_vacay_df["Rain/Inches"] == 0) &
                                    (city_vacay_df["Snow"] == 0)]

else:
    answer_filter_df = city_vacay_df.loc[(city_vacay_df["Max Temp"]<= max_temp) &
                                    (city_vacay_df["Max Temp"] >= min_temp) &
                                    (city_vacay_df["Rain/Inches"] == 0) &
                                    (city_vacay_df["Snow"] == 0)]

# %%
# Show table with city info matching rain/snow criteria
answer_filter_df.head()
# Out:
# Empty DataFrame
# Columns: [City_ID, City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Weather Desc, Rain/Inches, Snow]
# Index: []

# %%
# Create dataframe based on desired climates
desired_travel_areas = answer_filter_df.dropna()
desired_travel_areas
# Out:
# Empty DataFrame
# Columns: [City_ID, City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Weather Desc, Rain/Inches, Snow]
# Index: []

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = desired_travel_areas[["Lat", "Lng"]]
max_temp = desired_travel_areas["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# <ipython-input-50-7414df8c91ae> in <module>
#       3 max_temp = desired_travel_areas["Max Temp"]
#       4 fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# ----> 5 heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False, max_intensity=300, point_radius=4)
#       6 marker_layer = gmaps.marker_layer(locations)
#       7 fig.add_layer(heat_layer)
#
# ~\.conda\envs\PythonData\lib\site-packages\gmaps\heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     267     )
#     268     if is_weighted:
# --> 269         return WeightedHeatmap(**widget_args)
#     270     else:
#     271         return Heatmap(**widget_args)
#
# ~\.conda\envs\PythonData\lib\site-packages\ipywidgets\widgets\widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~\.conda\envs\PythonData\lib\site-packages\traitlets\traitlets.py in __init__(self, *args, **kwargs)
#     995             for key, value in kwargs.items():
#     996                 if self.has_trait(key):
# --> 997                     setattr(self, key, value)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
#
# ~\.conda\envs\PythonData\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\.conda\envs\PythonData\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# ~\.conda\envs\PythonData\lib\site-packages\traitlets\traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# ~\.conda\envs\PythonData\lib\site-packages\gmaps\geotraitlets.py in validate(self, obj, value)
#      27             _validate_latitude(latitude)
#      28             _validate_longitude(longitude)
# ---> 29         return super(LocationArray, self).validate(obj, locations_as_list)
#      30
#      31
#
# ~\.conda\envs\PythonData\lib\site-packages\traitlets\traitlets.py in validate(self, obj, value)
#    2322
#    2323     def validate(self, obj, value):
# -> 2324         value = super(List, self).validate(obj, value)
#    2325         value = self.validate_elements(obj, value)
#    2326         return value
#
# ~\.conda\envs\PythonData\lib\site-packages\traitlets\traitlets.py in validate(self, obj, value)
#    2240             return value
#    2241
# -> 2242         value = self.validate_elements(obj, value)
#    2243
#    2244         return value
#
# ~\.conda\envs\PythonData\lib\site-packages\traitlets\traitlets.py in validate_elements(self, obj, value)
#    2317         length = len(value)
#    2318         if length < self._minlen or length > self._maxlen:
# -> 2319             self.length_error(obj, value)
#    2320
#    2321         return super(List, self).validate_elements(obj, value)
#
# ~\.conda\envs\PythonData\lib\site-packages\traitlets\traitlets.py in length_error(self, obj, value)
#    2312         e = "The '%s' trait of %s instance must be of length %i <= L <= %i, but a value of %s was specified." \
#    2313             % (self.name, class_of(obj), self._minlen, self._maxlen, value)
# -> 2314         raise TraitError(e)
#    2315
#    2316     def validate_elements(self, obj, value):
#
# TraitError: The 'locations' trait of a WeightedHeatmap instance must be of length 1 <= L <= 9223372036854775807, but a value of [] was specified.

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPyPrac_vacay.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
##### Save and upload the new marker layer map as WeatherPy_vacation_map.png.

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID         City Country                 Date    Lat     Lng  Max Temp  \
# 0        0    Busselton      AU  2020-04-17 00:07:02 -33.65  115.33     55.99
# 1        1  Provideniya      RU  2020-04-17 00:06:31  64.38 -173.30     32.00
# 2        2       Hobart      AU  2020-04-17 00:06:02 -42.88  147.33     51.80
# 3        3         Lebu      CL  2020-04-17 00:07:03 -37.62  -73.65     56.30
# 4        4      Mataura      NZ  2020-04-17 00:07:03 -46.19  168.86     46.00
#
#    Humidity  Cloudiness  Wind Speed
# 0        61          13        8.05
# 1        97          90       13.42
# 2        53          75       21.92
# 3        87          10        8.70
# 4        94         100        8.01

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]

# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
    
# Assign the figure variable.
fig = gmaps.figure()

# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=temps)

# Add the heatmap layer.
fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
heat_layer = gmaps.heatmap_layer(locations, weights=temps, dissipating=False, max_intensity=2000, point_radius=20)
heat_layer
# Out:
# WeightedHeatmap(data_bounds=[(-47.58598988398036, -179.99999), (85.0, 179.99999)], dissipating=False, location…

# %%
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent wind speed
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 80
# What is the maximum temperature you would like for your trip? 100

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID         City Country                 Date    Lat     Lng  \
# 9         9   Georgetown      MY  2020-04-17 00:04:24   5.41  100.34
# 11       11       Avarua      CK  2020-04-17 00:06:33 -21.21 -159.78
# 18       18    La Quinta      US  2020-04-17 00:02:18  33.66 -116.31
# 24       24  Black River      JM  2020-04-17 00:07:08  18.03  -77.85
# 30       30        Ambon      ID  2020-04-17 00:04:43  -3.70  128.18
# 33       33        Kapaa      US  2020-04-17 00:03:51  22.08 -159.32
# 38       38        Hobyo      SO  2020-04-17 00:07:12   5.35   48.53
# 40       40    Kununurra      AU  2020-04-17 00:07:12 -15.77  128.73
# 48       48       Mackay      AU  2020-04-17 00:07:14 -21.15  149.20
# 51       51       Mapimi      MX  2020-04-17 00:07:15  25.82 -103.85
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 9      80.60        88          40        3.51
# 11     82.40        61          92        5.82
# 18     87.01        16           1       11.41
# 24     82.40        78          75        6.93
# 30     86.00        74          20        3.36
# 33     82.40        65          20       12.75
# 38     84.02        76          65       11.68
# 40     82.40        69          97        1.12
# 48     82.99        78          37        8.05
# 51     89.60        10          75       10.29

# %%
preferred_cities_df.count()
# Out:
# City_ID       102
# City          102
# Country       102
# Date          102
# Lat           102
# Lng           102
# Max Temp      102
# Humidity      102
# Cloudiness    102
# Wind Speed    102
# dtype: int64

# %%
preferred_cities_df.isnull().sum()
# Out:
# City_ID       0
# City          0
# Country       0
# Date          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# dtype: int64

# %%
preferred_cities_df.notnull().sum()
# Out:
# City_ID       102
# City          102
# Country       102
# Date          102
# Lat           102
# Lng           102
# Max Temp      102
# Humidity      102
# Cloudiness    102
# Wind Speed    102
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(177)
# Out:
#             City Country  Max Temp    Lat     Lng Hotel Name
# 9     Georgetown      MY     80.60   5.41  100.34
# 11        Avarua      CK     82.40 -21.21 -159.78
# 18     La Quinta      US     87.01  33.66 -116.31
# 24   Black River      JM     82.40  18.03  -77.85
# 30         Ambon      ID     86.00  -3.70  128.18
# ..           ...     ...       ...    ...     ...        ...
# 540      Kingman      US     87.01  35.19 -114.05
# 543   Port Keats      AU     83.23 -14.25  129.55
# 547  San Alberto      CO     82.13   7.76  -73.39
# 551  Salinopolis      BR     81.18  -0.61  -47.36
# 564        Alofi      NU     80.10 -19.06 -169.92
#
# [102 rows x 6 columns]

# %%
#https://maps.googleapis.com/maps/api/place/nearbysearch/output?parameters

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 10000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}

params["location"] = "22.29, 114.16"

# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()
hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHAEAALTIZg0598JrBF0bNVXf30DdOwAVQqXgpO8dda0BmrfNpbmES6nrvULE0oXacmu1SQqEmFsoX-kheADXbBZl65XlUXURIRngeWF7VwEchjwqaJrOnxm-tKuYqwye3qB6b1PBloXzOMCci_k4QGUVo3BkViSYQ9bC8BZ74yZ-lRneVMopGebljuseRCf5nh7zeRrWJ-h4jq5vFRvkns1NbsXJj6Xw2scls7LdIG8CzGIQs46xfIO-HK6Tq5Tj4ZgnErlZrbFncq71ZLzJ0GoDsvSIvr8UA2qJGnjyVEDYFOGeC32UGbpxRAtmukxIq4VlIndOTHD4-5ROA1R1MsGKwBsiuQj1zRnB_Ya3C4hcf-MIRBJ8lft_ad5GlQSiYS1IMRIQEr-x8UGWW8NR-tecLiwg2hoUoPeIV_WOebEFXFb8O_IBrhYUoP8',
#  'results': [{'geometry': {'location': {'lat': 22.280489, 'lng': 114.15634},
#     'viewport': {'northeast': {'lat': 22.2817839802915,
#       'lng': 114.1576528302915},
#      'southwest': {'lat': 22.2790860197085, 'lng': 114.1549548697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '802ea784b13876d2463e151cc74d165f36d89bd7',
#    'name': 'Mini Hotel Central',
#    'photos': [{'height': 1800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105750405296102675932">Mini Hotel Central</a>'],
#      'photo_reference': 'CmRaAAAAm8tuRZ9JJeQqofnBIK32KCzKM0iGG3LxqUq4k1a6Jh8mNEsmxuHyGu-WQmRluBzpoUPN7Qd6Wh90P0fnyFIo-04jS7SNa1Dxnv9JzisW7i3tiLfPiaQJeko1Dta7zb07EhD_YCsmd3k0pygoblY1UoU6GhRuqdkDD8ieI6JNgUu0Yhzr8ADhug',
#      'width': 1200}],
#    'place_id': 'ChIJAzBsKmUABDQRPgsNEjgJvO4',
#    'plus_code': {'compound_code': '75J4+5G Central, Hong Kong',
#     'global_code': '7PJP75J4+5G'},
#    'rating': 3.4,
#    'reference': 'ChIJAzBsKmUABDQRPgsNEjgJvO4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 848,
#    'vicinity': '38 號 Ice House Street, Central'},
#   {'geometry': {'location': {'lat': 22.295347, 'lng': 114.1710035},
#     'viewport': {'northeast': {'lat': 22.2964197802915,
#       'lng': 114.1725068302915},
#      'southwest': {'lat': 22.2937218197085, 'lng': 114.1698088697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '347953a6d9f3069e7de64279dc6d2541cc9aaec5',
#    'name': 'The Salisbury - YMCA of Hong Kong',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3744,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104629985414677815742">The Salisbury - YMCA of Hong Kong</a>'],
#      'photo_reference': 'CmRaAAAAm4TgcEsOvOWaD9sL1lzVIw_mtCBwuf_Kiw1t6etVmyU1oxTxmtT2ZiS18jk_AOpxZbwvXpVLUh86gDhcPBDjvMcUxwgRUZHPXTSimwS4SjKOsTW8lS_-QwVY2-pS-HJAEhAuG9CbSes9te1tRscxhYn3GhSvuf5XD_WaoDnRHPMR3iISdb_LuA',
#      'width': 5616}],
#    'place_id': 'ChIJPSa0VfIABDQR8HU8aU5yKN8',
#    'plus_code': {'compound_code': '75WC+4C Tsim Sha Tsui, Hong Kong',
#     'global_code': '7PJP75WC+4C'},
#    'rating': 4.2,
#    'reference': 'ChIJPSa0VfIABDQR8HU8aU5yKN8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2082,
#    'vicinity': '41 Salisbury Road, Tsim Sha Tsui'},
#   {'geometry': {'location': {'lat': 22.29510239999999, 'lng': 114.1718537},
#     'viewport': {'northeast': {'lat': 22.2962427802915,
#       'lng': 114.1732206302915},
#      'southwest': {'lat': 22.29354481970849, 'lng': 114.1705226697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'd2b16ed7ea271937cf4247cdc56a49f1440fd0a5',
#    'name': 'The Peninsula Hong Kong',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 465,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109648871846093552260">The Peninsula Hong Kong</a>'],
#      'photo_reference': 'CmRaAAAAPp60vclVDJoI05KnYNt6OEz-d8BcWXvdXrIarsab-vMJEpSU0eV2J9bMcgitSG70Tg92iZE16s-jvOTf-rQVPUMBCNiQjEws0HWS7gQjdUdYN17oKs2bi6qpumOJg84NEhDTVt93ZUqnL0SjtQ7-L_T2GhTWG7jd2nEGUdThgY0z4b2aUOECMA',
#      'width': 559}],
#    'place_id': 'ChIJdRlVSfIABDQRq5S65hPQo-8',
#    'plus_code': {'compound_code': '75WC+2P Tsim Sha Tsui, Hong Kong',
#     'global_code': '7PJP75WC+2P'},
#    'rating': 4.5,
#    'reference': 'ChIJdRlVSfIABDQRq5S65hPQo-8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4837,
#    'vicinity': 'Salisbury Road, Tsim Sha Tsui'},
#   {'geometry': {'location': {'lat': 22.2957152, 'lng': 114.1717745},
#     'viewport': {'northeast': {'lat': 22.2969834802915,
#       'lng': 114.1733576802915},
#      'southwest': {'lat': 22.2942855197085, 'lng': 114.1706597197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'b7ebfaf6801ef8c6e371836fabc7319d0ca69f03',
#    'name': 'The Kowloon Hotel',
#    'photos': [{'height': 1500,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101521386828949458677">The Kowloon Hotel</a>'],
#      'photo_reference': 'CmRaAAAAR9KSkBmlNH7Tmv2zArNSgMopMbCJmnCM1oz8VRJrX07NbofkOiY-k8KJJ3SxYLAnfBKco0CIjN2IV5JCcf5ondsYCY5J6Ez3cqc09llreoosWY2IgpgXTG4z90TvmmvTEhCcRrMTIQIvHWmbEqcgq0GdGhQO7Ma-FE_stawuJdwSr4dhqL4duA',
#      'width': 1049}],
#    'place_id': 'ChIJ94MYou8ABDQRa5ctqPrGouA',
#    'plus_code': {'compound_code': '75WC+7P Tsim Sha Tsui, Hong Kong',
#     'global_code': '7PJP75WC+7P'},
#    'rating': 3.9,
#    'reference': 'ChIJ94MYou8ABDQRa5ctqPrGouA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2796,
#    'vicinity': 'The Kowloon Hotel, Nathan Road, Tsim Sha Tsui'},
#   {'geometry': {'location': {'lat': 22.3034608, 'lng': 114.1602184},
#     'viewport': {'northeast': {'lat': 22.3049011302915,
#       'lng': 114.1614423302915},
#      'southwest': {'lat': 22.3022031697085, 'lng': 114.1587443697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '7d64b187dff487673729b4703626179e5bf1bff5',
#    'name': 'The Ritz-Carlton, Hong Kong',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112544691247100982474">The Ritz-Carlton, Hong Kong</a>'],
#      'photo_reference': 'CmRaAAAA2sTDqpX4_QBUHGQGItvu67vy4xkEADS9Cjm7r168wJ9GDPnirc_3y6ONUmurTojnzBVKUSFRH1o2-L_DVeCJiCqKuGwqnG1WXGlAqfHxVdUk9PNi46UcFYc77Bru3ZTNEhASZ5El-vyIXS2KWeKcUFQ1GhRNFGJYXAl1wdGu1fbS5H-AM_OAqw',
#      'width': 2048}],
#    'place_id': 'ChIJsz7XbJEABDQRhZtEqR96mI0',
#    'plus_code': {'compound_code': '8536+93 West Kowloon, Hong Kong',
#     'global_code': '7PJP8536+93'},
#    'rating': 4.6,
#    'reference': 'ChIJsz7XbJEABDQRhZtEqR96mI0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1266,
#    'vicinity': 'International Commerce Centre (ICC), 1 Austin Road West, West Kowloon'},
#   {'geometry': {'location': {'lat': 22.2967632, 'lng': 114.1729379},
#     'viewport': {'northeast': {'lat': 22.2981659302915,
#       'lng': 114.1740227802915},
#      'southwest': {'lat': 22.2954679697085, 'lng': 114.1713248197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'ac752001f457e951ad23689d503a8ea842a82d85',
#    'name': 'Holiday Inn Golden Mile Hong Kong',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2662,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106529197886718431020">Holiday Inn Golden Mile Hong Kong</a>'],
#      'photo_reference': 'CmRaAAAAtTxPOxfrVwPB1SdlkyQZZLjjF9Hb6zOZNovhi3x9GgV7x1fjqKm2BhEg7_Ca8dF3YeyYcQCd6A9HfV3kDXtaR12Q-P-YndEWew6xOslpt_DCaBXf2AFMIvwb_STvWLT7EhAdPBHAClZzgysPW39MdTIxGhSZ4lCUJq67WwZIOmxfTB6dLnhn5g',
#      'width': 4000}],
#    'place_id': 'ChIJ8SgJDvIABDQRgA6YPZc8epg',
#    'plus_code': {'compound_code': '75WF+P5 Tsim Sha Tsui, Hong Kong',
#     'global_code': '7PJP75WF+P5'},
#    'rating': 4.1,
#    'reference': 'ChIJ8SgJDvIABDQRgA6YPZc8epg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3144,
#    'vicinity': '50 Nathan Road, Tsim Sha Tsui'},
#   {'geometry': {'location': {'lat': 22.280174, 'lng': 114.171111},
#     'viewport': {'northeast': {'lat': 22.2817294802915,
#       'lng': 114.1725167802915},
#      'southwest': {'lat': 22.2790315197085, 'lng': 114.1698188197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'c241618a4f713439a7d5d27a52c6abeed3f91d95',
#    'name': 'The Harbourview',
#    'photos': [{'height': 2048,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111420334895253789922">The Harbourview</a>'],
#      'photo_reference': 'CmRaAAAAIpq-HkApIz1Vrc6gFMjmXCVz9oqmtj4ZO8QI3wCQH6rIBPvvAera3p2fddeyu3aDIcDmi_sw_0Pgky-TusOHTi6r5h922cSYyJ-efTF8p9jC4HQz0fcUZ3j95TcCZ_eNEhCTZDJ_m6bq8jOm5GlApWrTGhT28vJGBOQqRyZzesiGY3poGg4VLQ',
#      'width': 1355}],
#    'place_id': 'ChIJUUoEMlwABDQRf9H0ooj1FVY',
#    'plus_code': {'compound_code': '75JC+3C Wan Chai, Hong Kong',
#     'global_code': '7PJP75JC+3C'},
#    'rating': 3.9,
#    'reference': 'ChIJUUoEMlwABDQRf9H0ooj1FVY',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1288,
#    'vicinity': '4 Harbour Road, Wan Chai'},
#   {'geometry': {'location': {'lat': 22.3000224, 'lng': 114.172422},
#     'viewport': {'northeast': {'lat': 22.3013798302915,
#       'lng': 114.1735877802915},
#      'southwest': {'lat': 22.29868186970849, 'lng': 114.1708898197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'd7e9c8b4797aef11135ad11affc69ec6344f0b50',
#    'name': 'The Mira Hong Kong, a Member of Design Hotels',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1230,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110770754360642119935">The Mira Hong Kong, a Member of Design Hotels</a>'],
#      'photo_reference': 'CmRaAAAAUKMkO8BRo9q_aQMLLN-Q9Od8ofYh-VhtsNyg7u2_yKidd1Yc8viSlUWYkvV5P42Fyydv0j4deguUuUVn_r8etPUHWys7fHUJeqp5_dqUlgff928Kx9hKEVKy6P-Nr9DeEhBg-NG3_pFojenwLBo5hCQOGhSjLGyTwelHvI1V0ZDOfz_7mOrupw',
#      'width': 825}],
#    'place_id': 'ChIJ5zGete0ABDQRiMFCaPXrGYQ',
#    'plus_code': {'compound_code': '852C+2X Tsim Sha Tsui, Hong Kong',
#     'global_code': '7PJP852C+2X'},
#    'rating': 4.1,
#    'reference': 'ChIJ5zGete0ABDQRiMFCaPXrGYQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2509,
#    'vicinity': '118 Nathan Road, Tsim Sha Tsui'},
#   {'geometry': {'location': {'lat': 22.281513, 'lng': 114.173782},
#     'viewport': {'northeast': {'lat': 22.2824147802915,
#       'lng': 114.1752896302915},
#      'southwest': {'lat': 22.2797168197085, 'lng': 114.1725916697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '496a617203f3d1aea17fc38e6b8e1faff0d1ec92',
#    'name': 'Renaissance Hong Kong Harbour View Hotel',
#    'photos': [{'height': 550,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114585562719040874686">Renaissance Hong Kong Harbour View Hotel</a>'],
#      'photo_reference': 'CmRaAAAAUo9mYItJdloY_q6QXpqHsHfW4ll_YXliKL7fNAC5MDriCu-TetHWos0VmnELUKmqRYCQwu3sIJtl6fUh-U8MWqdXUGZjfIMZQ45bWDOQWxs0uWOiTWZuYylmA4d-KFNWEhA8gkOIAfPzCrVosGjvkR7EGhRPblKDYri0kot63hY-oRBmmauFLg',
#      'width': 1200}],
#    'place_id': 'ChIJM6O9TFkABDQRwnJ75YVlUwI',
#    'plus_code': {'compound_code': '75JF+JG Wan Chai, Hong Kong',
#     'global_code': '7PJP75JF+JG'},
#    'rating': 4.3,
#    'reference': 'ChIJM6O9TFkABDQRwnJ75YVlUwI',
#    'scope': 'GOOGLE',
#    'types': ['cafe',
#     'lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 3170,
#    'vicinity': '1 Harbour Road, Wan Chai'},
#   {'geometry': {'location': {'lat': 22.278358, 'lng': 114.171173},
#     'viewport': {'northeast': {'lat': 22.2796103302915,
#       'lng': 114.1724710802915},
#      'southwest': {'lat': 22.27691236970849, 'lng': 114.1697731197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '6bad91d085aec27393656821d8759602019f5743',
#    'name': 'Wharney Guang Dong Hotel Hong Kong',
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115655450556351862992">Ahmed Amzed</a>'],
#      'photo_reference': 'CmRaAAAAeK7l3how03lm_kFZtXbeypCCvR8q37T6qbi68YFJtbdOMnRbcn_iQYYa4HZJfaHpR-6kPh6DhPPfX3V1Av97J-PNFnN5Cq3Lb5J8HiQVUODZx_6Nfhxgf6U8Odc8jqTkEhAko7g9GnljneaYPXtp2VklGhTfdx5vnUy7bIm4xnqMHuFIGFumFA',
#      'width': 1920}],
#    'place_id': 'ChIJ3dnIVlwABDQRzughU2TrhyI',
#    'plus_code': {'compound_code': '75HC+8F Wan Chai, Hong Kong',
#     'global_code': '7PJP75HC+8F'},
#    'rating': 3.8,
#    'reference': 'ChIJ3dnIVlwABDQRzughU2TrhyI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1028,
#    'vicinity': '57 73Lockhart Road, Wan Chai'},
#   {'geometry': {'location': {'lat': 22.2976908, 'lng': 114.1748298},
#     'viewport': {'northeast': {'lat': 22.2990363802915,
#       'lng': 114.1760556302915},
#      'southwest': {'lat': 22.2963384197085, 'lng': 114.1733576697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '9c8acc729e1f1dd791434672804805d1364929b0',
#    'name': 'Hotel Panorama',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 918,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117715032388458480206">Zole Cheung</a>'],
#      'photo_reference': 'CmRaAAAALrrSkMIj-5Zww-yI9wunWqxPocdroD9w0kVolfAOPoe6Wr0_nfFNcsvbjJJQZC8OAtbBqqwwlY3xGMYGMlQ3cYqAOeTeEYPikadSn7ujPUHLvCNLR-kLJI285SRRznaLEhBzYAvzaPoGMHvuIdYddf70GhTpGleK3UXFPhHxEJ7ff-WNwS53VQ',
#      'width': 3426}],
#    'place_id': 'ChIJ81aqEO4ABDQR0Jl0OQliWvM',
#    'plus_code': {'compound_code': '75XF+3W Tsim Sha Tsui, Hong Kong',
#     'global_code': '7PJP75XF+3W'},
#    'rating': 3.9,
#    'reference': 'ChIJ81aqEO4ABDQR0Jl0OQliWvM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 973,
#    'vicinity': '8A號 Hart Avenue, Tsim Sha Tsui'},
#   {'geometry': {'location': {'lat': 22.3005805, 'lng': 114.1737669},
#     'viewport': {'northeast': {'lat': 22.3020399802915,
#       'lng': 114.1751891302915},
#      'southwest': {'lat': 22.2993420197085, 'lng': 114.1724911697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'c569ab8dffd939930396d482b678691e87e969b6',
#    'name': 'The Kimberley Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117706059604893016076">Ricardo Agustin López</a>'],
#      'photo_reference': 'CmRaAAAAL2rEUZ7q1WTiG9zg3zLV64D0GR3MwV9gKXz2hk7IZZgcsASgSJQDzqO8tuuL-C64ll7Q9dYqc-Vsyd_AParZmV1t3PTbV1T0rQA2G9rkxnkdOFTCsdnEoZ1oQNh7ft_zEhBkYieobyYuO6VGEdadovIRGhSmhLNsPhXZ8b5S6whm9PNo7NNl-w',
#      'width': 5312}],
#    'place_id': 'ChIJOen1gu4ABDQRYHJXBrQ3ZF4',
#    'plus_code': {'compound_code': '852F+6G Tsim Sha Tsui, Hong Kong',
#     'global_code': '7PJP852F+6G'},
#    'rating': 3.7,
#    'reference': 'ChIJOen1gu4ABDQRYHJXBrQ3ZF4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1870,
#    'vicinity': '28 Kimberley Road, Tsim Sha Tsui'},
#   {'geometry': {'location': {'lat': 22.2996468, 'lng': 114.1754107},
#     'viewport': {'northeast': {'lat': 22.3009248302915,
#       'lng': 114.1768837302915},
#      'southwest': {'lat': 22.2982268697085, 'lng': 114.1741857697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '1ad2b09d053b0b1968de0490885b837a65fde0dc',
#    'name': 'Park Hotel Hong Kong',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104621449732975900205">Park Hotel Hong Kong</a>'],
#      'photo_reference': 'CmRaAAAAd2tKzq1OMZZQ4IMRkQsFz51LcpnrBUmHbttsQ4LEJtJ4ODnexkWhFf1_xgdlUsg9z9PD5b8SXyZkDjCS19Va5CUq4CKlW0z1NfMt0ESrc7TSrDXC1rJ44VOWLHlTmklIEhBTDvC8rZQAo8RYx5xBD7aCGhRJyPL48ttxTe8PxLLR7ryBx0sWmA',
#      'width': 6048}],
#    'place_id': 'ChIJ38usWO4ABDQRMx0gYvo07xs',
#    'plus_code': {'compound_code': '75XG+V5 Tsim Sha Tsui, Hong Kong',
#     'global_code': '7PJP75XG+V5'},
#    'rating': 4.1,
#    'reference': 'ChIJ38usWO4ABDQRMx0gYvo07xs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1648,
#    'vicinity': 'Park Hotel Hong Kong, Chatham Road South, Tsim Sha Tsui'},
#   {'geometry': {'location': {'lat': 22.3040416, 'lng': 114.1719858},
#     'viewport': {'northeast': {'lat': 22.3054868802915,
#       'lng': 114.1733277302915},
#      'southwest': {'lat': 22.3027889197085, 'lng': 114.1706297697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '746fdabf4480cbc9734d8382973a9e3fed3e8999',
#    'name': 'Prudential Hotel',
#    'photos': [{'height': 5344,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115805695946863837204">Andy Leung</a>'],
#      'photo_reference': 'CmRaAAAAt-XV1Hhw7SeGcWBmTzXV8UIYpAdqAxIZ3gwCso_w-UQshSxtzQwHuE5O3JYcezZf4w8DVrytjSVGP-BCCl_eaL2np7UJg0kHvbWFntTQIdWUSaQ6l7IAcbZt-v-F_6KXEhBc3sn4y1t9Xp1IR3-kL1LhGhRJIGZIr1fhI_WotvHFmxKUx1oaBA',
#      'width': 3006}],
#    'place_id': 'ChIJ6eMJlesABDQRBsThn7cd5oY',
#    'plus_code': {'compound_code': '853C+JQ Tsim Sha Tsui, Hong Kong',
#     'global_code': '7PJP853C+JQ'},
#    'rating': 3.8,
#    'reference': 'ChIJ6eMJlesABDQRBsThn7cd5oY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1967,
#    'vicinity': '222 Nathan Road, Tsim Sha Tsui'},
#   {'geometry': {'location': {'lat': 22.2788043, 'lng': 114.176386},
#     'viewport': {'northeast': {'lat': 22.2801260802915,
#       'lng': 114.1778066302915},
#      'southwest': {'lat': 22.2774281197085, 'lng': 114.1751086697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '67b01968bdb6fcb9cb2b998a87c1be6cad8e7e3f',
#    'name': 'Novotel Hong Kong Century',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2413,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113542245374609046569">Novotel Hong Kong Century</a>'],
#      'photo_reference': 'CmRaAAAAV2FLNIcOjBde-Cl-Q9wkUPK_h5O4cKvhEFzibWdlygdLQ7ttkqwUyH-gFFTRiV_l55DXlfjT2IPuzP1veCq8hLD_P9pJUXAMy5nUF_L2ds_mLkDSQOWiLnpSxclshUFTEhDB1giSBoHBWNhyv_guwLR7GhRDcd1agJTyJjdEK1KAEW_48x_bpQ',
#      'width': 3620}],
#    'place_id': 'ChIJfwqQylsABDQRqt7PVlBkoaM',
#    'plus_code': {'compound_code': '75HG+GH Wan Chai, Hong Kong',
#     'global_code': '7PJP75HG+GH'},
#    'rating': 4,
#    'reference': 'ChIJfwqQylsABDQRqt7PVlBkoaM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2847,
#    'vicinity': '238 Jaffe Road, Wan Chai'},
#   {'geometry': {'location': {'lat': 22.2988492, 'lng': 114.1780266},
#     'viewport': {'northeast': {'lat': 22.3000931802915,
#       'lng': 114.1792675302915},
#      'southwest': {'lat': 22.2973952197085, 'lng': 114.1765695697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'a011360d73850c4f62e3a032240ce406625ca947',
#    'name': 'Regal Kowloon Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1247,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111946643890758337016">Regal Kowloon Hotel</a>'],
#      'photo_reference': 'CmRaAAAALskmPn3-XyyGX8l-82O-1RqiXGcYHPEHdrKp8iQv9mUVHrnxTX_IWjXY2AnofGdpbvt7DiUUbZWYDsLVwC3PWO2gVuQ0AGXAp6eJ3_5o8ppz5uM0_ahCg2E1ermp0lEHEhDH6oeMecXN0-2VUpezbxw_GhRWwIc2EWgvxqZpobPaK--35UI60A',
#      'width': 2048}],
#    'place_id': 'ChIJryIlou8ABDQRL1bq4LgfZtk',
#    'plus_code': {'compound_code': '75XH+G6 Tsim Sha Tsui East, Hong Kong',
#     'global_code': '7PJP75XH+G6'},
#    'rating': 3.9,
#    'reference': 'ChIJryIlou8ABDQRL1bq4LgfZtk',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 2493,
#    'vicinity': '71 Mody Road, Tsim Sha Tsui East'},
#   {'geometry': {'location': {'lat': 22.28728, 'lng': 114.139121},
#     'viewport': {'northeast': {'lat': 22.2886407302915,
#       'lng': 114.1403392302915},
#      'southwest': {'lat': 22.28594276970849, 'lng': 114.1376412697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '10661d3d73b42af9a3cd62dd3379cc14f11482a0',
#    'name': 'Best Western Plus Hotel Hong Kong 華大盛品酒店',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3609,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109835270386633205433">Best Western Plus Hotel Hong Kong 華大盛品酒店</a>'],
#      'photo_reference': 'CmRaAAAAc907iPtMNfWvVBEDZpufJLs7xr2l8LaG2DZPanisOF3b0ncfjKM7PPU4LfQXSgzPzrRanRX3SbWq3IAJldRteQCNelzXVFab_m7HrKHM7-RzHWRy7O5JnVGCapROTa8LEhDP0PGs0Vum_vZhs3zgS1JhGhTdaIk9-HmLYII0NiD5GPG_Eko4KA',
#      'width': 2608}],
#    'place_id': 'ChIJewz8QYH_AzQRzRa9Gq-0NsE',
#    'plus_code': {'compound_code': '74PQ+WJ Sai Ying Pun, Hong Kong',
#     'global_code': '7PJP74PQ+WJ'},
#    'rating': 3.6,
#    'reference': 'ChIJewz8QYH_AzQRzRa9Gq-0NsE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1140,
#    'vicinity': '308 Des Voeux Road West, Sai Ying Pun'},
#   {'geometry': {'location': {'lat': 22.2879472, 'lng': 114.1388493},
#     'viewport': {'northeast': {'lat': 22.2892633802915,
#       'lng': 114.1400861302915},
#      'southwest': {'lat': 22.2865654197085, 'lng': 114.1373881697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'ecff685d7f52a9f525771242233fefa3f5a89a72',
#    'name': 'Courtyard by Marriott Hong Kong',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 423,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117688898917883965518">Courtyard by Marriott Hong Kong</a>'],
#      'photo_reference': 'CmRaAAAA5QdSjylAE2QuEWrsIXgcq5GstiZDlhsZT1dfCvL3qdMP22Fd8Ol7ZOeSOeW4GvKCFaYVNTguGUwCwxDnA4G2eDZLPYuM4vdCYwcVrBsE3SF4f4YFbxNxbVTgu2j4UZu4EhA36DlktrC8YdSYw1w2tEf5GhSDlufRzQl9Ps9lsxck5atIWLuVQA',
#      'width': 370}],
#    'place_id': 'ChIJ86Wyb4H_AzQRii6NZVjo81A',
#    'plus_code': {'compound_code': '74QQ+5G Sai Ying Pun, Hong Kong',
#     'global_code': '7PJP74QQ+5G'},
#    'price_level': 3,
#    'rating': 4.1,
#    'reference': 'ChIJ86Wyb4H_AzQRii6NZVjo81A',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 798,
#    'vicinity': '167 Connaught Road West, Sai Ying Pun'},
#   {'geometry': {'location': {'lat': 22.298993, 'lng': 114.179327},
#     'viewport': {'northeast': {'lat': 22.3005702302915,
#       'lng': 114.1804773302915},
#      'southwest': {'lat': 22.2978722697085, 'lng': 114.1777793697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'f6e0fd849c0bd18dc9507839af93e9b62c9eac8e',
#    'name': 'InterContinental Grand Stanford Hong Kong',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3158,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101716618103558120760">InterContinental Grand Stanford Hong Kong</a>'],
#      'photo_reference': 'CmRaAAAAQHfdvZpVOL8tVjf-Cl-nPUmaQYlEbGqmZoZzBsEkh6RfEXfo-6Nj18rAPVlz3DbKL8Ojk9H9LGESJigAMY7Wt7jXim7tAhiVw-ERMZ6iI9XaIji2Fg-cU7WQsfnyr5C-EhCeRxoxCb8tgGUtXPtw929dGhRFvDEufl8VW7jvbLa1pqbQrxlGVQ',
#      'width': 6695}],
#    'place_id': 'ChIJKYaYze8ABDQRlx3xy15WKaI',
#    'plus_code': {'compound_code': '75XH+HP Tsim Sha Tsui, Hong Kong',
#     'global_code': '7PJP75XH+HP'},
#    'rating': 4.3,
#    'reference': 'ChIJKYaYze8ABDQRlx3xy15WKaI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2459,
#    'vicinity': '70號 Mody Road, Tsim Sha Tsui'},
#   {'geometry': {'location': {'lat': 22.3073031, 'lng': 114.1720799},
#     'viewport': {'northeast': {'lat': 22.3085455302915,
#       'lng': 114.1734589302915},
#      'southwest': {'lat': 22.3058475697085, 'lng': 114.1707609697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '59726d851e0738cd0bfc27434f566afc1a1473fb',
#    'name': 'Novotel Hong Kong Nathan Road Kowloon',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118108949055556178940">Novotel Hong Kong Nathan Road Kowloon</a>'],
#      'photo_reference': 'CmRaAAAA7gNA4_PfJoQfyiWzEn2tAoeSgXNQj_6RAiPon1tOMnqClPuhr0tz6lpX_f1_95wlO7sAG2Fs95fQ6mewS6W-QsVD94t0qADV-Y0ZZXLW3qbN44EBFweeDcZf1QEby_mqEhCriDbizRRE3HCgUZge9ayxGhQQqKbditTVdn3cNtGrxrroRjS1QA',
#      'width': 2048}],
#    'place_id': 'ChIJK0XuQuoABDQRahqYK6zkVXI',
#    'plus_code': {'compound_code': '854C+WR Yau Ma Tei, Hong Kong',
#     'global_code': '7PJP854C+WR'},
#    'rating': 4,
#    'reference': 'ChIJK0XuQuoABDQRahqYK6zkVXI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2516,
#    'vicinity': '348 Nathan Road, Yau Ma Tei'}],
#  'status': 'OK'}

# %%
#hotels["results"][0]

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
   
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
   
  # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head(10)
# Out:
#            City Country  Max Temp    Lat     Lng  \
# 9    Georgetown      MY     80.60   5.41  100.34
# 11       Avarua      CK     82.40 -21.21 -159.78
# 18    La Quinta      US     87.01  33.66 -116.31
# 24  Black River      JM     82.40  18.03  -77.85
# 30        Ambon      ID     86.00  -3.70  128.18
# 33        Kapaa      US     82.40  22.08 -159.32
# 38        Hobyo      SO     84.02   5.35   48.53
# 40    Kununurra      AU     82.40 -15.77  128.73
# 48       Mackay      AU     82.99 -21.15  149.20
# 51       Mapimi      MX     89.60  25.82 -103.85
#
#                                         Hotel Name
# 9                                   Cititel Penang
# 11                        Little Polynesian Resort
# 18  Embassy Suites by Hilton La Quinta Hotel & Spa
# 24                        Idlers' Rest Beach Hotel
# 30                            Swiss-Belhotel Ambon
# 33          Sheraton Kauai Resort at Coconut Beach
# 38
# 40                                 Hotel Kununurra
# 48             Windmill Motel and Reception Centre
# 51                                  Propiedad Lldm

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Name</dt><dd>{column1}</dd>
<dt>Another name</dt><dd>{column2}</dd>
</dl>
"""
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
