# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import scipy
import timeit
import requests

# Import the commands and config info
import citipy
from citipy import citipy

from scipy import stats
from scipy.stats import linregress
from config import weather_api_key
from datetime import datetime

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 90) + random.random()
    latitudes.append(random_lat)
    x += 1
latitudes
# Out:
# [-30.991126262618053,
#  -12.053628184282799,
#  7.112136848694568,
#  42.268337116803636,
#  -87.15529132592054,
#  25.455144933627675,
#  36.25334390820893,
#  55.63557228188739,
#  58.218563703195514,
#  24.279588864007795]

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 605

# %%
#https://samples.openweathermap.org/data/2.5/weather?q=London,uk&appid=439d4b804bc8187953eb36d2a8c26a02

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weatherdesc = city_weather["weather"][0]["description"]
        try:
            city_rain = city_weather["rain"]
        except:
            city_rain = 0
        try:
            city_snow = city_weather["snow"]
        except:
            city_snow = 0
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Desc": city_weatherdesc,
                          "Rain/Inches": city_rain,
                          "Snow": city_snow,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | grindavik
# Processing Record 3 of Set 1 | clyde river
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | bambous virieux
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | langsa
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | cherdyn
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | praia da vitoria
# Processing Record 15 of Set 1 | san patricio
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | chuy
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | cascais
# Processing Record 22 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 1 | esperance
# Processing Record 24 of Set 1 | agva
# City not found. Skipping...
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 1 | yongan
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | kirakira
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | kishi
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | eureka
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | sambava
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | shkotovo-26
# City not found. Skipping...
# Processing Record 39 of Set 1 | nexo
# Processing Record 40 of Set 1 | nara
# Processing Record 41 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 1 | haines junction
# Processing Record 43 of Set 1 | asfi
# Processing Record 44 of Set 1 | tiznit
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | anadyr
# Processing Record 48 of Set 1 | hobyo
# Processing Record 49 of Set 1 | bardiyah
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | dekoa
# City not found. Skipping...
# Processing Record 2 of Set 2 | chokurdakh
# Processing Record 3 of Set 2 | tucupita
# Processing Record 4 of Set 2 | tautira
# Processing Record 5 of Set 2 | namatanai
# Processing Record 6 of Set 2 | husavik
# Processing Record 7 of Set 2 | douentza
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | minden
# Processing Record 10 of Set 2 | faanui
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | sechura
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | rehoboth
# Processing Record 16 of Set 2 | fene
# Processing Record 17 of Set 2 | huanuco
# Processing Record 18 of Set 2 | cabedelo
# Processing Record 19 of Set 2 | george town
# Processing Record 20 of Set 2 | busselton
# Processing Record 21 of Set 2 | vestmanna
# Processing Record 22 of Set 2 | namie
# Processing Record 23 of Set 2 | bali
# Processing Record 24 of Set 2 | sitka
# Processing Record 25 of Set 2 | cabo san lucas
# Processing Record 26 of Set 2 | kudahuvadhoo
# Processing Record 27 of Set 2 | yulara
# Processing Record 28 of Set 2 | ostrovnoy
# Processing Record 29 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | okhotsk
# Processing Record 31 of Set 2 | butaritari
# Processing Record 32 of Set 2 | cam ranh
# Processing Record 33 of Set 2 | namibe
# Processing Record 34 of Set 2 | acajutla
# Processing Record 35 of Set 2 | barahan
# Processing Record 36 of Set 2 | castro
# Processing Record 37 of Set 2 | viedma
# Processing Record 38 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 39 of Set 2 | ushuaia
# Processing Record 40 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 2 | ponta do sol
# Processing Record 42 of Set 2 | sai buri
# Processing Record 43 of Set 2 | bilibino
# Processing Record 44 of Set 2 | georgetown
# Processing Record 45 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 2 | narsaq
# Processing Record 47 of Set 2 | cravo norte
# Processing Record 48 of Set 2 | tairua
# Processing Record 49 of Set 2 | leningradskiy
# Processing Record 50 of Set 2 | saint george
# Processing Record 1 of Set 3 | atuona
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | paramonga
# Processing Record 5 of Set 3 | henties bay
# Processing Record 6 of Set 3 | pevek
# Processing Record 7 of Set 3 | grafton
# Processing Record 8 of Set 3 | karwar
# Processing Record 9 of Set 3 | imbituba
# Processing Record 10 of Set 3 | belaya gora
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | dongning
# Processing Record 13 of Set 3 | saint-georges
# Processing Record 14 of Set 3 | ilesha
# Processing Record 15 of Set 3 | iqaluit
# Processing Record 16 of Set 3 | voh
# Processing Record 17 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 3 | beloha
# Processing Record 19 of Set 3 | vlasim
# Processing Record 20 of Set 3 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 21 of Set 3 | san quintin
# Processing Record 22 of Set 3 | acapulco
# Processing Record 23 of Set 3 | beni suef
# Processing Record 24 of Set 3 | sur
# Processing Record 25 of Set 3 | shingu
# Processing Record 26 of Set 3 | beringovskiy
# Processing Record 27 of Set 3 | kruisfontein
# Processing Record 28 of Set 3 | batang berjuntai
# Processing Record 29 of Set 3 | saint-joseph
# Processing Record 30 of Set 3 | dikson
# Processing Record 31 of Set 3 | pisco
# Processing Record 32 of Set 3 | port lincoln
# Processing Record 33 of Set 3 | ancud
# Processing Record 34 of Set 3 | takoradi
# Processing Record 35 of Set 3 | olafsvik
# Processing Record 36 of Set 3 | southbridge
# Processing Record 37 of Set 3 | bumba
# Processing Record 38 of Set 3 | omboue
# Processing Record 39 of Set 3 | ahipara
# Processing Record 40 of Set 3 | payo
# Processing Record 41 of Set 3 | victor harbor
# Processing Record 42 of Set 3 | nyurba
# Processing Record 43 of Set 3 | comodoro rivadavia
# Processing Record 44 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 3 | hutchinson
# Processing Record 46 of Set 3 | puerto ayora
# Processing Record 47 of Set 3 | centralia
# Processing Record 48 of Set 3 | bulgan
# Processing Record 49 of Set 3 | waipawa
# Processing Record 50 of Set 3 | kahului
# Processing Record 1 of Set 4 | ilulissat
# Processing Record 2 of Set 4 | mar del plata
# Processing Record 3 of Set 4 | panjab
# Processing Record 4 of Set 4 | qaanaaq
# Processing Record 5 of Set 4 | lorengau
# Processing Record 6 of Set 4 | yellowknife
# Processing Record 7 of Set 4 | ailigandi
# Processing Record 8 of Set 4 | banff
# Processing Record 9 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 4 | takhli
# Processing Record 11 of Set 4 | qaqortoq
# Processing Record 12 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 4 | astana
# Processing Record 15 of Set 4 | thompson
# Processing Record 16 of Set 4 | bud
# Processing Record 17 of Set 4 | mehamn
# Processing Record 18 of Set 4 | beinamar
# Processing Record 19 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 20 of Set 4 | ucluelet
# Processing Record 21 of Set 4 | urumqi
# Processing Record 22 of Set 4 | dunedin
# Processing Record 23 of Set 4 | panjakent
# Processing Record 24 of Set 4 | kapaa
# Processing Record 25 of Set 4 | soe
# Processing Record 26 of Set 4 | andselv
# City not found. Skipping...
# Processing Record 27 of Set 4 | matara
# Processing Record 28 of Set 4 | saint-francois
# Processing Record 29 of Set 4 | severo-kurilsk
# Processing Record 30 of Set 4 | newnan
# Processing Record 31 of Set 4 | armidale
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | teya
# Processing Record 34 of Set 4 | kutum
# Processing Record 35 of Set 4 | gamba
# Processing Record 36 of Set 4 | orchard homes
# Processing Record 37 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 4 | champasak
# Processing Record 39 of Set 4 | hobart
# Processing Record 40 of Set 4 | klaksvik
# Processing Record 41 of Set 4 | tilichiki
# Processing Record 42 of Set 4 | bolshaya dzhalga
# Processing Record 43 of Set 4 | axim
# Processing Record 44 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 4 | hirna
# Processing Record 46 of Set 4 | ibra
# Processing Record 47 of Set 4 | mount isa
# Processing Record 48 of Set 4 | karasjok
# Processing Record 49 of Set 4 | smithers
# Processing Record 50 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 5 | namangan
# Processing Record 3 of Set 5 | magdagachi
# Processing Record 4 of Set 5 | luderitz
# Processing Record 5 of Set 5 | ust-tsilma
# Processing Record 6 of Set 5 | lanquin
# Processing Record 7 of Set 5 | chumikan
# Processing Record 8 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 5 | lima
# Processing Record 10 of Set 5 | kristiinankaupunki
# Processing Record 11 of Set 5 | kaili
# Processing Record 12 of Set 5 | rawson
# Processing Record 13 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 5 | pires do rio
# Processing Record 15 of Set 5 | kondinskoye
# Processing Record 16 of Set 5 | nanortalik
# Processing Record 17 of Set 5 | kautokeino
# Processing Record 18 of Set 5 | hithadhoo
# Processing Record 19 of Set 5 | saquena
# Processing Record 20 of Set 5 | torbay
# Processing Record 21 of Set 5 | cidreira
# Processing Record 22 of Set 5 | shu
# Processing Record 23 of Set 5 | vagur
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | kodiak
# Processing Record 26 of Set 5 | ciras
# City not found. Skipping...
# Processing Record 27 of Set 5 | san policarpo
# Processing Record 28 of Set 5 | qujing
# Processing Record 29 of Set 5 | victoria
# Processing Record 30 of Set 5 | dalaba
# Processing Record 31 of Set 5 | katsuura
# Processing Record 32 of Set 5 | port-gentil
# Processing Record 33 of Set 5 | sabang
# Processing Record 34 of Set 5 | sistranda
# Processing Record 35 of Set 5 | pirapemas
# Processing Record 36 of Set 5 | puerto baquerizo moreno
# Processing Record 37 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 5 | nouadhibou
# Processing Record 39 of Set 5 | moyale
# Processing Record 40 of Set 5 | awbari
# Processing Record 41 of Set 5 | airai
# Processing Record 42 of Set 5 | lata
# Processing Record 43 of Set 5 | bontang
# Processing Record 44 of Set 5 | tambo
# Processing Record 45 of Set 5 | vila velha
# Processing Record 46 of Set 5 | plouzane
# Processing Record 47 of Set 5 | milford
# Processing Record 48 of Set 5 | bethel
# Processing Record 49 of Set 5 | makakilo city
# Processing Record 50 of Set 5 | lugovoy
# Processing Record 1 of Set 6 | goderich
# Processing Record 2 of Set 6 | sunndalsora
# Processing Record 3 of Set 6 | gondar
# Processing Record 4 of Set 6 | januaria
# Processing Record 5 of Set 6 | pangody
# Processing Record 6 of Set 6 | seymchan
# Processing Record 7 of Set 6 | alofi
# Processing Record 8 of Set 6 | blagoyevo
# Processing Record 9 of Set 6 | cradock
# Processing Record 10 of Set 6 | isangel
# Processing Record 11 of Set 6 | tsentralnyy
# City not found. Skipping...
# Processing Record 12 of Set 6 | navahrudak
# Processing Record 13 of Set 6 | copiapo
# Processing Record 14 of Set 6 | san cristobal
# Processing Record 15 of Set 6 | unai
# Processing Record 16 of Set 6 | golden
# Processing Record 17 of Set 6 | saskylakh
# Processing Record 18 of Set 6 | svetlogorsk
# Processing Record 19 of Set 6 | ayan
# Processing Record 20 of Set 6 | carutapera
# Processing Record 21 of Set 6 | najran
# Processing Record 22 of Set 6 | pingxiang
# Processing Record 23 of Set 6 | tomatlan
# Processing Record 24 of Set 6 | torremolinos
# Processing Record 25 of Set 6 | caravelas
# Processing Record 26 of Set 6 | khatanga
# Processing Record 27 of Set 6 | belyy yar
# Processing Record 28 of Set 6 | santo antonio do ica
# Processing Record 29 of Set 6 | nelson bay
# Processing Record 30 of Set 6 | lashio
# Processing Record 31 of Set 6 | itoman
# Processing Record 32 of Set 6 | hibbing
# Processing Record 33 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 6 | norman wells
# Processing Record 35 of Set 6 | east london
# Processing Record 36 of Set 6 | adrar
# Processing Record 37 of Set 6 | vermilion
# Processing Record 38 of Set 6 | skjervoy
# Processing Record 39 of Set 6 | belmonte
# Processing Record 40 of Set 6 | kade
# Processing Record 41 of Set 6 | bukama
# Processing Record 42 of Set 6 | nador
# Processing Record 43 of Set 6 | betul
# Processing Record 44 of Set 6 | baoning
# Processing Record 45 of Set 6 | homer
# Processing Record 46 of Set 6 | bichura
# Processing Record 47 of Set 6 | talaya
# Processing Record 48 of Set 6 | suntar
# Processing Record 49 of Set 6 | opuwo
# Processing Record 50 of Set 6 | cayenne
# Processing Record 1 of Set 7 | kidal
# Processing Record 2 of Set 7 | saldanha
# Processing Record 3 of Set 7 | balagansk
# Processing Record 4 of Set 7 | omsukchan
# Processing Record 5 of Set 7 | souillac
# Processing Record 6 of Set 7 | nogales
# Processing Record 7 of Set 7 | stromness
# Processing Record 8 of Set 7 | kamina
# Processing Record 9 of Set 7 | tuatapere
# Processing Record 10 of Set 7 | abu samrah
# Processing Record 11 of Set 7 | tlaxiaco
# City not found. Skipping...
# Processing Record 12 of Set 7 | turukhansk
# Processing Record 13 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 7 | livingston
# Processing Record 15 of Set 7 | guiratinga
# Processing Record 16 of Set 7 | arlit
# Processing Record 17 of Set 7 | la tuque
# Processing Record 18 of Set 7 | biak
# Processing Record 19 of Set 7 | gilgit
# Processing Record 20 of Set 7 | boyolangu
# Processing Record 21 of Set 7 | yichun
# Processing Record 22 of Set 7 | codrington
# Processing Record 23 of Set 7 | lincoln
# Processing Record 24 of Set 7 | meulaboh
# Processing Record 25 of Set 7 | kloulklubed
# Processing Record 26 of Set 7 | hami
# Processing Record 27 of Set 7 | rio gallegos
# Processing Record 28 of Set 7 | rovaniemi
# Processing Record 29 of Set 7 | mbekenyera
# Processing Record 30 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 7 | sisimiut
# Processing Record 32 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 7 | havre-saint-pierre
# Processing Record 34 of Set 7 | nishihara
# Processing Record 35 of Set 7 | pacific grove
# Processing Record 36 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 7 | mongo
# Processing Record 38 of Set 7 | esso
# Processing Record 39 of Set 7 | gat
# Processing Record 40 of Set 7 | nuevo progreso
# Processing Record 41 of Set 7 | nizwa
# Processing Record 42 of Set 7 | quelimane
# Processing Record 43 of Set 7 | galle
# Processing Record 44 of Set 7 | caruray
# Processing Record 45 of Set 7 | lasa
# Processing Record 46 of Set 7 | bom jesus da lapa
# Processing Record 47 of Set 7 | bilma
# Processing Record 48 of Set 7 | tindwari
# Processing Record 49 of Set 7 | fuyu
# Processing Record 50 of Set 7 | micheweni
# Processing Record 1 of Set 8 | bjelovar
# Processing Record 2 of Set 8 | creetown
# Processing Record 3 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 8 | kuryk
# Processing Record 5 of Set 8 | te anau
# Processing Record 6 of Set 8 | laguna
# Processing Record 7 of Set 8 | lusambo
# Processing Record 8 of Set 8 | benidorm
# Processing Record 9 of Set 8 | constitucion
# Processing Record 10 of Set 8 | todos santos
# Processing Record 11 of Set 8 | athabasca
# Processing Record 12 of Set 8 | hamilton
# Processing Record 13 of Set 8 | kabinda
# Processing Record 14 of Set 8 | sinnamary
# Processing Record 15 of Set 8 | sioux lookout
# Processing Record 16 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 8 | havre de grace
# Processing Record 18 of Set 8 | huarmey
# Processing Record 19 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 8 | marsa matruh
# Processing Record 21 of Set 8 | kysyl-syr
# Processing Record 22 of Set 8 | los llanos de aridane
# Processing Record 23 of Set 8 | talavera de la reina
# Processing Record 24 of Set 8 | hambantota
# Processing Record 25 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 26 of Set 8 | sarevere
# Processing Record 27 of Set 8 | heihe
# Processing Record 28 of Set 8 | tessalit
# Processing Record 29 of Set 8 | marawi
# Processing Record 30 of Set 8 | coquimbo
# Processing Record 31 of Set 8 | karatau
# Processing Record 32 of Set 8 | fort nelson
# Processing Record 33 of Set 8 | labuhan
# Processing Record 34 of Set 8 | corowa
# Processing Record 35 of Set 8 | saint-philippe
# Processing Record 36 of Set 8 | longyearbyen
# Processing Record 37 of Set 8 | pandan
# Processing Record 38 of Set 8 | kavieng
# Processing Record 39 of Set 8 | rincon
# Processing Record 40 of Set 8 | sitio novo do tocantins
# Processing Record 41 of Set 8 | igrim
# Processing Record 42 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 8 | sola
# Processing Record 44 of Set 8 | san andres
# Processing Record 45 of Set 8 | horasan
# Processing Record 46 of Set 8 | buraydah
# Processing Record 47 of Set 8 | jiazi
# Processing Record 48 of Set 8 | ouallam
# Processing Record 49 of Set 8 | humaita
# Processing Record 50 of Set 8 | vila franca do campo
# Processing Record 1 of Set 9 | nizhniy kuranakh
# Processing Record 2 of Set 9 | portland
# Processing Record 3 of Set 9 | hovd
# Processing Record 4 of Set 9 | half moon bay
# Processing Record 5 of Set 9 | ilebo
# Processing Record 6 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 7 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 9 | banjar
# Processing Record 9 of Set 9 | ahuimanu
# Processing Record 10 of Set 9 | puerto del rosario
# Processing Record 11 of Set 9 | concordia
# Processing Record 12 of Set 9 | sao paulo de olivenca
# Processing Record 13 of Set 9 | bismarck
# Processing Record 14 of Set 9 | moosomin
# Processing Record 15 of Set 9 | mazatlan
# Processing Record 16 of Set 9 | tasiilaq
# Processing Record 17 of Set 9 | barstow
# Processing Record 18 of Set 9 | hvolsvollur
# Processing Record 19 of Set 9 | ballina
# Processing Record 20 of Set 9 | calama
# Processing Record 21 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 22 of Set 9 | labrea
# Processing Record 23 of Set 9 | pavlivka
# Processing Record 24 of Set 9 | keti bandar
# Processing Record 25 of Set 9 | baykit
# Processing Record 26 of Set 9 | tartus
# Processing Record 27 of Set 9 | sao joao da barra
# Processing Record 28 of Set 9 | itarema
# Processing Record 29 of Set 9 | polyarnyy
# Processing Record 30 of Set 9 | saint anthony
# Processing Record 31 of Set 9 | mugur-aksy
# Processing Record 32 of Set 9 | port hardy
# Processing Record 33 of Set 9 | divnomorskoye
# Processing Record 34 of Set 9 | koygorodok
# Processing Record 35 of Set 9 | mecca
# Processing Record 36 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 37 of Set 9 | khani
# Processing Record 38 of Set 9 | illapel
# Processing Record 39 of Set 9 | harper
# Processing Record 40 of Set 9 | muyezerskiy
# Processing Record 41 of Set 9 | pangnirtung
# Processing Record 42 of Set 9 | lakatoro
# Processing Record 43 of Set 9 | emerald
# Processing Record 44 of Set 9 | kargasok
# Processing Record 45 of Set 9 | fortuna
# Processing Record 46 of Set 9 | leczna
# Processing Record 47 of Set 9 | manitouwadge
# Processing Record 48 of Set 9 | samsun
# Processing Record 49 of Set 9 | xichang
# Processing Record 50 of Set 9 | jalu
# Processing Record 1 of Set 10 | ayotzintepec
# Processing Record 2 of Set 10 | sassandra
# Processing Record 3 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 10 | malindi
# Processing Record 5 of Set 10 | chapada dos guimaraes
# Processing Record 6 of Set 10 | monki
# Processing Record 7 of Set 10 | khuzhir
# Processing Record 8 of Set 10 | kaitangata
# Processing Record 9 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 10 of Set 10 | margate
# Processing Record 11 of Set 10 | antsohihy
# Processing Record 12 of Set 10 | manzhouli
# Processing Record 13 of Set 10 | minab
# Processing Record 14 of Set 10 | solnechnyy
# Processing Record 15 of Set 10 | pontes e lacerda
# Processing Record 16 of Set 10 | talara
# Processing Record 17 of Set 10 | denpasar
# Processing Record 18 of Set 10 | yar-sale
# Processing Record 19 of Set 10 | gold coast
# Processing Record 20 of Set 10 | sibolga
# Processing Record 21 of Set 10 | camopi
# Processing Record 22 of Set 10 | talnakh
# Processing Record 23 of Set 10 | hualmay
# Processing Record 24 of Set 10 | ugoofaaru
# Processing Record 25 of Set 10 | lompoc
# Processing Record 26 of Set 10 | tianjin
# Processing Record 27 of Set 10 | hasaki
# Processing Record 28 of Set 10 | igbo ora
# Processing Record 29 of Set 10 | taltal
# Processing Record 30 of Set 10 | fonte boa
# Processing Record 31 of Set 10 | gudur
# Processing Record 32 of Set 10 | srednekolymsk
# Processing Record 33 of Set 10 | bauchi
# Processing Record 34 of Set 10 | faya
# Processing Record 35 of Set 10 | beian
# Processing Record 36 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 37 of Set 10 | staryy nadym
# Processing Record 38 of Set 10 | muisne
# Processing Record 39 of Set 10 | kisangani
# Processing Record 40 of Set 10 | zyryanka
# Processing Record 41 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 10 | pombas
# Processing Record 43 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 44 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 10 | banikoara
# Processing Record 46 of Set 10 | zhigansk
# Processing Record 47 of Set 10 | aguimes
# Processing Record 48 of Set 10 | naples
# Processing Record 49 of Set 10 | kiruna
# Processing Record 50 of Set 10 | otradnoye
# Processing Record 1 of Set 11 | liepaja
# Processing Record 2 of Set 11 | vao
# Processing Record 3 of Set 11 | envira
# Processing Record 4 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 5 of Set 11 | rio grande
# Processing Record 6 of Set 11 | aksu
# Processing Record 7 of Set 11 | yerofey pavlovich
# Processing Record 8 of Set 11 | severnoye
# Processing Record 9 of Set 11 | jesup
# Processing Record 10 of Set 11 | colac
# Processing Record 11 of Set 11 | camacha
# Processing Record 12 of Set 11 | baiyin
# Processing Record 13 of Set 11 | moron
# Processing Record 14 of Set 11 | trairi
# Processing Record 15 of Set 11 | killybegs
# Processing Record 16 of Set 11 | muroto
# Processing Record 17 of Set 11 | saint-pierre
# Processing Record 18 of Set 11 | lavrentiya
# Processing Record 19 of Set 11 | mataram
# Processing Record 20 of Set 11 | bose
# Processing Record 21 of Set 11 | jacobina
# Processing Record 22 of Set 11 | bairiki
# Processing Record 23 of Set 11 | eldoret
# Processing Record 24 of Set 11 | boca do acre
# Processing Record 25 of Set 11 | maniitsoq
# Processing Record 26 of Set 11 | pundaguitan
# Processing Record 27 of Set 11 | pangai
# Processing Record 28 of Set 11 | nizhnekamsk
# Processing Record 29 of Set 11 | coahuayana
# Processing Record 30 of Set 11 | eyl
# Processing Record 31 of Set 11 | walvis bay
# Processing Record 32 of Set 11 | bengkulu
# Processing Record 33 of Set 11 | xadani
# City not found. Skipping...
# Processing Record 34 of Set 11 | qui nhon
# Processing Record 35 of Set 11 | kaputa
# Processing Record 36 of Set 11 | dakar
# Processing Record 37 of Set 11 | kedrovyy
# Processing Record 38 of Set 11 | bartica
# Processing Record 39 of Set 11 | le vauclin
# Processing Record 40 of Set 11 | sao filipe
# Processing Record 41 of Set 11 | jinxiang
# Processing Record 42 of Set 11 | luba
# Processing Record 43 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 44 of Set 11 | nemuro
# Processing Record 45 of Set 11 | saravan
# Processing Record 46 of Set 11 | bucerias
# Processing Record 47 of Set 11 | of
# City not found. Skipping...
# Processing Record 48 of Set 11 | nyaunglebin
# Processing Record 49 of Set 11 | kropotkin
# Processing Record 50 of Set 11 | baculin
# Processing Record 1 of Set 12 | huai thalaeng
# Processing Record 2 of Set 12 | gazni
# City not found. Skipping...
# Processing Record 3 of Set 12 | nelidovo
# Processing Record 4 of Set 12 | mattru
# Processing Record 5 of Set 12 | raga
# Processing Record 6 of Set 12 | antofagasta
# Processing Record 7 of Set 12 | keratea
# Processing Record 8 of Set 12 | riyadh
# Processing Record 9 of Set 12 | tshikapa
# Processing Record 10 of Set 12 | pauini
# Processing Record 11 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 14 of Set 12 | barcelona
# Processing Record 15 of Set 12 | middelburg
# Processing Record 16 of Set 12 | eenhana
# Processing Record 17 of Set 12 | vrangel
# Processing Record 18 of Set 12 | melekhovskaya
# City not found. Skipping...
# Processing Record 19 of Set 12 | helong
# Processing Record 20 of Set 12 | harrogate
# Processing Record 21 of Set 12 | kalmunai
# Processing Record 22 of Set 12 | outjo
# Processing Record 23 of Set 12 | vokhma
# Processing Record 24 of Set 12 | santa fe
# Processing Record 25 of Set 12 | grootfontein
# Processing Record 26 of Set 12 | bonaventure
# Processing Record 27 of Set 12 | broome
# Processing Record 28 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 12 | sahuaripa
# Processing Record 30 of Set 12 | cap malheureux
# Processing Record 31 of Set 12 | verkhnyaya sinyachikha
# Processing Record 32 of Set 12 | zhanaozen
# Processing Record 33 of Set 12 | santa cruz de la palma
# Processing Record 34 of Set 12 | winslow
# Processing Record 35 of Set 12 | santa isabel do rio negro
# Processing Record 36 of Set 12 | santa vitoria do palmar
# Processing Record 37 of Set 12 | nileshwar
# Processing Record 38 of Set 12 | bogorodskoye
# Processing Record 39 of Set 12 | bodden town
# Processing Record 40 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 41 of Set 12 | port hawkesbury
# Processing Record 42 of Set 12 | ilo
# Processing Record 43 of Set 12 | zhuhai
# Processing Record 44 of Set 12 | roald
# Processing Record 45 of Set 12 | beipiao
# Processing Record 46 of Set 12 | dwarka
# Processing Record 47 of Set 12 | coolum beach
# Processing Record 48 of Set 12 | zhitikara
# City not found. Skipping...
# Processing Record 49 of Set 12 | gizo
# Processing Record 50 of Set 12 | pedro ii
# Processing Record 1 of Set 13 | kingston
# Processing Record 2 of Set 13 | addi ugri
# City not found. Skipping...
# Processing Record 3 of Set 13 | the pas
# Processing Record 4 of Set 13 | verkhnevilyuysk
# Processing Record 5 of Set 13 | mozarlandia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
city_data_df
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Punta Arenas -53.15  -70.92     53.60        46          40
# 1          Grindavik  63.84  -22.43     35.60       100          90
# 2        Clyde River  70.47  -68.59     14.00        85          75
# 3    Arraial Do Cabo -22.97  -42.03     75.20        78          75
# 4             Albany  42.60  -73.97     46.00        71          93
# ..               ...    ...     ...       ...       ...         ...
# 537         Pedro Ii  -4.42  -41.46     71.40        82         100
# 538         Kingston  18.00  -76.79     84.20        74          40
# 539          The Pas  53.83 -101.25     24.80        45           1
# 540  Verkhnevilyuysk  63.45  120.32      4.33        93          57
# 541      Mozarlandia -14.74  -50.57     74.70        84         100
#
#      Wind Speed      Weather Desc   Rain/Inches Snow Country  \
# 0         19.46  scattered clouds             0    0      CL
# 1          9.17        light rain             0    0      IS
# 2          3.36        light snow             0    0      CA
# 3          4.70     broken clouds             0    0      BR
# 4          1.99        light rain  {'3h': 0.49}    0      US
# ..          ...               ...           ...  ...     ...
# 537        0.29     moderate rain  {'3h': 3.59}    0      BR
# 538       18.34  scattered clouds             0    0      JM
# 539       11.41         clear sky             0    0      CA
# 540        4.72     broken clouds             0    0      RU
# 541        1.77   overcast clouds             0    0      BR
#
#                     Date
# 0    2020-04-18 21:39:39
# 1    2020-04-18 21:39:39
# 2    2020-04-18 21:39:40
# 3    2020-04-18 21:39:40
# 4    2020-04-18 21:35:29
# ..                   ...
# 537  2020-04-18 21:41:49
# 538  2020-04-18 21:37:46
# 539  2020-04-18 21:41:50
# 540  2020-04-18 21:41:50
# 541  2020-04-18 21:41:50
#
# [542 rows x 12 columns]

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Weather Desc","Rain/Inches","Snow"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                 City Country                 Date    Lat     Lng  Max Temp  \
# 0       Punta Arenas      CL  2020-04-18 21:39:39 -53.15  -70.92     53.60
# 1          Grindavik      IS  2020-04-18 21:39:39  63.84  -22.43     35.60
# 2        Clyde River      CA  2020-04-18 21:39:40  70.47  -68.59     14.00
# 3    Arraial Do Cabo      BR  2020-04-18 21:39:40 -22.97  -42.03     75.20
# 4             Albany      US  2020-04-18 21:35:29  42.60  -73.97     46.00
# ..               ...     ...                  ...    ...     ...       ...
# 537         Pedro Ii      BR  2020-04-18 21:41:49  -4.42  -41.46     71.40
# 538         Kingston      JM  2020-04-18 21:37:46  18.00  -76.79     84.20
# 539          The Pas      CA  2020-04-18 21:41:50  53.83 -101.25     24.80
# 540  Verkhnevilyuysk      RU  2020-04-18 21:41:50  63.45  120.32      4.33
# 541      Mozarlandia      BR  2020-04-18 21:41:50 -14.74  -50.57     74.70
#
#      Humidity  Cloudiness  Wind Speed      Weather Desc   Rain/Inches Snow
# 0          46          40       19.46  scattered clouds             0    0
# 1         100          90        9.17        light rain             0    0
# 2          85          75        3.36        light snow             0    0
# 3          78          75        4.70     broken clouds             0    0
# 4          71          93        1.99        light rain  {'3h': 0.49}    0
# ..        ...         ...         ...               ...           ...  ...
# 537        82         100        0.29     moderate rain  {'3h': 3.59}    0
# 538        74          40       18.34  scattered clouds             0    0
# 539        45           1       11.41         clear sky             0    0
# 540        93          57        4.72     broken clouds             0    0
# 541        84         100        1.77   overcast clouds             0    0
#
# [542 rows x 12 columns]

# %%
len(city_data)
# Out:
# 542

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data_df)
city_data_df.head(10)
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0     Punta Arenas      CL  2020-04-18 21:39:39 -53.15  -70.92     53.60
# 1        Grindavik      IS  2020-04-18 21:39:39  63.84  -22.43     35.60
# 2      Clyde River      CA  2020-04-18 21:39:40  70.47  -68.59     14.00
# 3  Arraial Do Cabo      BR  2020-04-18 21:39:40 -22.97  -42.03     75.20
# 4           Albany      US  2020-04-18 21:35:29  42.60  -73.97     46.00
# 5          Rikitea      PF  2020-04-18 21:39:40 -23.12 -134.97     77.09
# 6  Bambous Virieux      MU  2020-04-18 21:39:40 -20.34   57.76     78.01
# 7      Port Alfred      ZA  2020-04-18 21:39:41 -33.59   26.89     63.00
# 8           Langsa      ID  2020-04-18 21:37:46   4.47   97.97     75.90
# 9             Hilo      US  2020-04-18 21:39:41  19.73 -155.09     82.40
#
#    Humidity  Cloudiness  Wind Speed      Weather Desc   Rain/Inches Snow
# 0        46          40       19.46  scattered clouds             0    0
# 1       100          90        9.17        light rain             0    0
# 2        85          75        3.36        light snow             0    0
# 3        78          75        4.70     broken clouds             0    0
# 4        71          93        1.99        light rain  {'3h': 0.49}    0
# 5        73          18        7.54        few clouds             0    0
# 6        88          40       14.99  scattered clouds             0    0
# 7        94           0        4.00         clear sky             0    0
# 8        91          99        2.39   overcast clouds             0    0
# 9        51          40       11.41  scattered clouds             0    0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
